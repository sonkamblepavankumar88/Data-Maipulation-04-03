# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('imdb_data.csv')

# %%
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# 0                        [{'id': 35, 'name': 'Comedy'}]
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                         [{'id': 18, 'name': 'Drama'}]
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# ...                                                 ...
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                homepage    imdb_id original_language  \
# 0                                   NaN  tt2637294                en
# 1                                   NaN  tt0368933                en
# 2     http://sonyclassics.com/whiplash/  tt2582802                en
# 3            http://kahaanithefilm.com/  tt1821480                hi
# 4                                   NaN  tt1380152                ko
# ...                                 ...        ...               ...
# 2995                                NaN  tt0109403                en
# 2996                                NaN  tt2364975                sv
# 2997                                NaN  tt0116908                en
# 2998     http://www.alongcamepolly.com/  tt0343135                en
# 2999   http://www.abductionthefilm.com/  tt1600195                en
#
#                                 original_title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                         마린보이
# ...                                        ...
# 2995                                   Chasers
# 2996                               Vi är bäst!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                overview  popularity  ...  \
# 0     When Lou, who has become the "father of the In...    6.575393  ...
# 1     Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2     Under the direction of a ruthless instructor, ...   64.299990  ...
# 3     Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4     Marine Boy is the story of a former national s...    1.148070  ...
# ...                                                 ...         ...  ...
# 2995  Military men Rock Reilly and Eddie Devane are ...    9.853270  ...
# 2996  Three girls in 1980s Stockholm decide to form ...    3.727996  ...
# 2997  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
# 2998  Reuben Feffer is a guy who's spent his entire ...   15.725542  ...
# 2999  A young man sets out to uncover the truth abou...   10.512109  ...
#
#      release_date runtime                                   spoken_languages  \
# 0         2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1          8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2        10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3          3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4          2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
# ...           ...     ...                                                ...
# 2995      4/22/94   102.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2996      3/28/13   102.0           [{'iso_639_1': 'sv', 'name': 'svenska'}]
# 2997     10/11/96   120.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2998      1/16/04    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2999      9/22/11   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#         status                                            tagline  \
# 0     Released  The Laws of Space and Time are About to be Vio...
# 1     Released  It can take a lifetime to find true love; she'...
# 2     Released    The road to greatness can take you to the edge.
# 3     Released                                                NaN
# 4     Released                                                NaN
# ...        ...                                                ...
# 2995  Released  It was supposed to be a routine prisoner trans...
# 2996  Released                                                NaN
# 2997  Released               What's forgotten is not always gone.
# 2998  Released  For the most cautious man on Earth, life is ab...
# 2999  Released          They stole his life. He's taking it back.
#
#                                          title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                   Marine Boy
# ...                                        ...
# 2995                                   Chasers
# 2996                          We Are the Best!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                Keywords  \
# 0     [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1     [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2     [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3     [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                   NaN
# ...                                                 ...
# 2995  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 2996  [{'id': 1192, 'name': 'sweden'}, {'id': 4470, ...
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#                                                    cast  \
# 0     [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1     [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2     [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3     [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4     [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# ...                                                 ...
# 2995  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2996  [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# 2997  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew    revenue
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...   12314651
# 1     [{'credit_id': '52fe43fe9251416c7502563d', 'de...   95149435
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...   13092000
# 3     [{'credit_id': '52fe48779251416c9108d6eb', 'de...   16000000
# 4     [{'credit_id': '52fe464b9251416c75073b43', 'de...    3923970
# ...                                                 ...        ...
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687
# 2996  [{'credit_id': '5716b72ac3a3686678012c84', 'de...     180590
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155
#
# [3000 rows x 23 columns]

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3000, step=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
#  14  runtime                2998 non-null   float64
#  15  spoken_languages       2980 non-null   object
#  16  status                 3000 non-null   object
#  17  tagline                2403 non-null   object
#  18  title                  3000 non-null   object
#  19  Keywords               2724 non-null   object
#  20  cast                   2987 non-null   object
#  21  crew                   2984 non-null   object
#  22  revenue                3000 non-null   int64
# dtypes: float64(2), int64(3), object(18)
# memory usage: 539.2+ KB

# %%
df.shape
# Out:
# (3000, 23)

# %%
df.head(7)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
# 5   6                                                NaN   8000000
# 6   7                                                NaN  14000000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 5  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 6  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
#
#                              homepage    imdb_id original_language  \
# 0                                 NaN  tt2637294                en
# 1                                 NaN  tt0368933                en
# 2   http://sonyclassics.com/whiplash/  tt2582802                en
# 3          http://kahaanithefilm.com/  tt1821480                hi
# 4                                 NaN  tt1380152                ko
# 5                                 NaN  tt0093743                en
# 6  http://www.thepossessionmovie.com/  tt0431021                en
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
# 5    Pinocchio and the Emperor of the Night
# 6                            The Possession
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
# 5  Pinocchio and his friends, a glow worm and a m...    0.743274  ...
# 6  A young girl buys an antique box at a yard sal...    7.286477  ...
#
#   release_date runtime                                   spoken_languages  \
# 0      2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1       8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2     10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4       2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
# 5       8/6/87    83.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 6      8/30/12    92.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released  The Laws of Space and Time are About to be Vio...
# 1  Released  It can take a lifetime to find true love; she'...
# 2  Released    The road to greatness can take you to the edge.
# 3  Released                                                NaN
# 4  Released                                                NaN
# 5  Released                                                NaN
# 6  Released               Fear The Demon That Doesn't Fear God
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
# 5    Pinocchio and the Emperor of the Night
# 6                            The Possession
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# 5  [{'cast_id': 6, 'character': 'Pinocchio (voice...
# 6  [{'cast_id': 23, 'character': 'Clyde', 'credit...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
# 5  [{'credit_id': '52fe46f49251416c9106558b', 'de...   3261638
# 6  [{'credit_id': '52fe4981c3a368484e12ee29', 'de...  85446075
#
# [7 rows x 23 columns]

# %%
df.tail(7)
# Out:
#         id belongs_to_collection    budget  \
# 2993  2994                   NaN  60000000
# 2994  2995                   NaN         0
# 2995  2996                   NaN         0
# 2996  2997                   NaN         0
# 2997  2998                   NaN  65000000
# 2998  2999                   NaN  42000000
# 2999  3000                   NaN  35000000
#
#                                                  genres  \
# 2993  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2994                      [{'id': 18, 'name': 'Drama'}]
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                   homepage    imdb_id original_language  \
# 2993  http://www.theterminal-themovie.com/  tt0362227                en
# 2994                                   NaN  tt0105327                en
# 2995                                   NaN  tt0109403                en
# 2996                                   NaN  tt2364975                sv
# 2997                                   NaN  tt0116908                en
# 2998        http://www.alongcamepolly.com/  tt0343135                en
# 2999      http://www.abductionthefilm.com/  tt1600195                en
#
#                original_title  \
# 2993             The Terminal
# 2994              School Ties
# 2995                  Chasers
# 2996              Vi är bäst!
# 2997  The Long Kiss Goodnight
# 2998         Along Came Polly
# 2999                Abduction
#
#                                                overview  popularity  ...  \
# 2993  Viktor Navorski is a man without a country; hi...   14.092373  ...
# 2994  When David Greene receives a football scholars...    7.438381  ...
# 2995  Military men Rock Reilly and Eddie Devane are ...    9.853270  ...
# 2996  Three girls in 1980s Stockholm decide to form ...    3.727996  ...
# 2997  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
# 2998  Reuben Feffer is a guy who's spent his entire ...   15.725542  ...
# 2999  A young man sets out to uncover the truth abou...   10.512109  ...
#
#      release_date runtime                                   spoken_languages  \
# 2993      6/17/04   128.0  [{'iso_639_1': 'bg', 'name': 'български език'}...
# 2994      9/18/92   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2995      4/22/94   102.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2996      3/28/13   102.0           [{'iso_639_1': 'sv', 'name': 'svenska'}]
# 2997     10/11/96   120.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2998      1/16/04    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2999      9/22/11   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#         status                                            tagline  \
# 2993  Released                                   Life is waiting.
# 2994  Released  Just because you’re accepted doesn’t mean you ...
# 2995  Released  It was supposed to be a routine prisoner trans...
# 2996  Released                                                NaN
# 2997  Released               What's forgotten is not always gone.
# 2998  Released  For the most cautious man on Earth, life is ab...
# 2999  Released          They stole his life. He's taking it back.
#
#                         title  \
# 2993             The Terminal
# 2994              School Ties
# 2995                  Chasers
# 2996         We Are the Best!
# 2997  The Long Kiss Goodnight
# 2998         Along Came Polly
# 2999                Abduction
#
#                                                Keywords  \
# 2993  [{'id': 242, 'name': 'new york'}, {'id': 822, ...
# 2994  [{'id': 6075, 'name': 'sport'}, {'id': 10144, ...
# 2995  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 2996  [{'id': 1192, 'name': 'sweden'}, {'id': 4470, ...
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#                                                    cast  \
# 2993  [{'cast_id': 4, 'character': 'Viktor Navorski'...
# 2994  [{'cast_id': 2, 'character': 'David Greene', '...
# 2995  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2996  [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# 2997  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew    revenue
# 2993  [{'credit_id': '52fe4259c3a36847f8017699', 'de...  219417255
# 2994  [{'credit_id': '5637777ac3a3681b4d01f9f5', 'de...   14715067
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687
# 2996  [{'credit_id': '5716b72ac3a3686678012c84', 'de...     180590
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155
#
# [7 rows x 23 columns]

# %%
df.describe()
# Out:
#                 id        budget   popularity      runtime       revenue
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09

# %%
df.head(10)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
# 5   6                                                NaN   8000000
# 6   7                                                NaN  14000000
# 7   8                                                NaN         0
# 8   9  [{'id': 256377, 'name': 'The Muppet Collection...         0
# 9  10                                                NaN   6000000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 5  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 6  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 7                [{'id': 99, 'name': 'Documentary'}]
# 8  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 9  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
#
#                              homepage    imdb_id original_language  \
# 0                                 NaN  tt2637294                en
# 1                                 NaN  tt0368933                en
# 2   http://sonyclassics.com/whiplash/  tt2582802                en
# 3          http://kahaanithefilm.com/  tt1821480                hi
# 4                                 NaN  tt1380152                ko
# 5                                 NaN  tt0093743                en
# 6  http://www.thepossessionmovie.com/  tt0431021                en
# 7                                 NaN  tt0391024                en
# 8                                 NaN  tt0117110                en
# 9                                 NaN  tt0310281                en
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
# 5    Pinocchio and the Emperor of the Night
# 6                            The Possession
# 7                              Control Room
# 8                    Muppet Treasure Island
# 9                             A Mighty Wind
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
# 5  Pinocchio and his friends, a glow worm and a m...    0.743274  ...
# 6  A young girl buys an antique box at a yard sal...    7.286477  ...
# 7  A chronicle which provides a rare window into ...    1.949044  ...
# 8  After telling the story of Flint's last journe...    6.902423  ...
# 9  In "A Mighty Wind", director Christopher Guest...    4.672036  ...
#
#   release_date runtime                                   spoken_languages  \
# 0      2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1       8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2     10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4       2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
# 5       8/6/87    83.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 6      8/30/12    92.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 7      1/15/04    84.0  [{'iso_639_1': 'ar', 'name': 'العربية'}, {'iso...
# 8      2/16/96   100.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 9      4/16/03    91.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released  The Laws of Space and Time are About to be Vio...
# 1  Released  It can take a lifetime to find true love; she'...
# 2  Released    The road to greatness can take you to the edge.
# 3  Released                                                NaN
# 4  Released                                                NaN
# 5  Released                                                NaN
# 6  Released               Fear The Demon That Doesn't Fear God
# 7  Released              Different channels. Different truths.
# 8  Released                        Set sail for Muppet mayhem!
# 9  Released           Back together for the first time, again.
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
# 5    Pinocchio and the Emperor of the Night
# 6                            The Possession
# 7                              Control Room
# 8                    Muppet Treasure Island
# 9                             A Mighty Wind
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7  [{'id': 917, 'name': 'journalism'}, {'id': 163...
# 8  [{'id': 2041, 'name': 'island'}, {'id': 4418, ...
# 9  [{'id': 11800, 'name': 'mockumentary'}, {'id':...
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# 5  [{'cast_id': 6, 'character': 'Pinocchio (voice...
# 6  [{'cast_id': 23, 'character': 'Clyde', 'credit...
# 7  [{'cast_id': 2, 'character': 'Himself', 'credi...
# 8  [{'cast_id': 1, 'character': 'Long John Silver...
# 9  [{'cast_id': 24, 'character': 'Jonathan Steinb...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
# 5  [{'credit_id': '52fe46f49251416c9106558b', 'de...   3261638
# 6  [{'credit_id': '52fe4981c3a368484e12ee29', 'de...  85446075
# 7  [{'credit_id': '52fe47a69251416c750a0daf', 'de...   2586511
# 8  [{'credit_id': '52fe43c89251416c7501deb3', 'de...  34327391
# 9  [{'credit_id': '52fe45609251416c750545b3', 'de...  18750246
#
# [10 rows x 23 columns]

# %%
# Let us get a subject which consists of all rows and last

df.iloc[:,-3:]
# Out:
#                                                    cast  \
# 0     [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1     [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2     [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3     [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4     [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# ...                                                 ...
# 2995  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2996  [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# 2997  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew    revenue
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...   12314651
# 1     [{'credit_id': '52fe43fe9251416c7502563d', 'de...   95149435
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...   13092000
# 3     [{'credit_id': '52fe48779251416c9108d6eb', 'de...   16000000
# 4     [{'credit_id': '52fe464b9251416c75073b43', 'de...    3923970
# ...                                                 ...        ...
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687
# 2996  [{'credit_id': '5716b72ac3a3686678012c84', 'de...     180590
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155
#
# [3000 rows x 3 columns]

# %%
df.iloc[:,-5:-3]
# Out:
#                                          title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                   Marine Boy
# ...                                        ...
# 2995                                   Chasers
# 2996                          We Are the Best!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                Keywords
# 0     [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1     [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2     [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3     [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                   NaN
# ...                                                 ...
# 2995  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 2996  [{'id': 1192, 'name': 'sweden'}, {'id': 4470, ...
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
# [3000 rows x 2 columns]

# %%
df.iloc[1:3]
# Out:
#    id                              belongs_to_collection    budget  \
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
#
#                                               genres  \
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
#
#                             homepage    imdb_id original_language  \
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
#
#                              original_title  \
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
#
#                                             overview  popularity  ...  \
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
#
#   release_date runtime                          spoken_languages    status  \
# 1       8/6/04   113.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2     10/10/14   105.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 1  It can take a lifetime to find true love; she'...
# 2    The road to greatness can take you to the edge.
#
#                                       title  \
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
#
#                                             Keywords  \
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
#
#                                                 cast  \
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
#
#                                                 crew   revenue
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
#
# [2 rows x 23 columns]

# %%
df.iloc[0:5:2]
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 2   3                                                NaN   3300000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 2                      [{'id': 18, 'name': 'Drama'}]
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 4                                NaN  tt1380152                ko
#
#            original_title                                           overview  \
# 0  Hot Tub Time Machine 2  When Lou, who has become the "father of the In...
# 2                Whiplash  Under the direction of a ruthless instructor, ...
# 4                    마린보이  Marine Boy is the story of a former national s...
#
#    popularity  ... release_date runtime  \
# 0    6.575393  ...      2/20/15    93.0
# 2   64.299990  ...     10/10/14   105.0
# 4    1.148070  ...       2/5/09   118.0
#
#                            spoken_languages    status  \
# 0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 4  [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
#
#                                              tagline                   title  \
# 0  The Laws of Space and Time are About to be Vio...  Hot Tub Time Machine 2
# 2    The road to greatness can take you to the edge.                Whiplash
# 4                                                NaN              Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970
#
# [3 rows x 23 columns]

# %%
df.loc[0:10,['id','budget']]
# Out:
#     id    budget
# 0    1  14000000
# 1    2  40000000
# 2    3   3300000
# 3    4   1200000
# 4    5         0
# 5    6   8000000
# 6    7  14000000
# 7    8         0
# 8    9         0
# 9   10   6000000
# 10  11   1000000

# %%
df.loc[:,['id', 'budget','genres','runtime']]
# Out:
#         id    budget                                             genres  \
# 0        1  14000000                     [{'id': 35, 'name': 'Comedy'}]
# 1        2  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2        3   3300000                      [{'id': 18, 'name': 'Drama'}]
# 3        4   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4        5         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# ...    ...       ...                                                ...
# 2995  2996         0  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  2997         0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  2998  65000000  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  2999  42000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  3000  35000000  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#       runtime
# 0        93.0
# 1       113.0
# 2       105.0
# 3       122.0
# 4       118.0
# ...       ...
# 2995    102.0
# 2996    102.0
# 2997    120.0
# 2998     90.0
# 2999    106.0
#
# [3000 rows x 4 columns]

# %%
df.loc[40:46,['id', 'budget','genres','runtime']]
# Out:
#     id    budget                                             genres  runtime
# 40  41         0  [{'id': 28, 'name': 'Action'}, {'id': 99, 'nam...    118.0
# 41  42   3000000  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...    126.0
# 42  43  25000000                     [{'id': 35, 'name': 'Comedy'}]    108.0
# 43  44   6000000                      [{'id': 18, 'name': 'Drama'}]     92.0
# 44  45  15000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...     88.0
# 45  46   3906840  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...     95.0
# 46  47  80000000  [{'id': 16, 'name': 'Animation'}, {'id': 10751...     91.0

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
df['original_language']=='en'
# Out:
# 0        True
# 1        True
# 2        True
# 3       False
# 4       False
#         ...
# 2995     True
# 2996    False
# 2997     True
# 2998     True
# 2999     True
# Name: original_language, Length: 3000, dtype: bool

# %%
#Boolean Indexing

english_movies = df[df['original_language'] == 'en']
english_movies.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 5   6                                                NaN   8000000
# 6   7                                                NaN  14000000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 5  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 6  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
#
#                              homepage    imdb_id original_language  \
# 0                                 NaN  tt2637294                en
# 1                                 NaN  tt0368933                en
# 2   http://sonyclassics.com/whiplash/  tt2582802                en
# 5                                 NaN  tt0093743                en
# 6  http://www.thepossessionmovie.com/  tt0431021                en
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 5    Pinocchio and the Emperor of the Night
# 6                            The Possession
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 5  Pinocchio and his friends, a glow worm and a m...    0.743274  ...
# 6  A young girl buys an antique box at a yard sal...    7.286477  ...
#
#   release_date runtime                          spoken_languages    status  \
# 0      2/20/15    93.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1       8/6/04   113.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2     10/10/14   105.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 5       8/6/87    83.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 6      8/30/12    92.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0  The Laws of Space and Time are About to be Vio...
# 1  It can take a lifetime to find true love; she'...
# 2    The road to greatness can take you to the edge.
# 5                                                NaN
# 6               Fear The Demon That Doesn't Fear God
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 5    Pinocchio and the Emperor of the Night
# 6                            The Possession
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 5                                                NaN
# 6                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 5  [{'cast_id': 6, 'character': 'Pinocchio (voice...
# 6  [{'cast_id': 23, 'character': 'Clyde', 'credit...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 5  [{'credit_id': '52fe46f49251416c9106558b', 'de...   3261638
# 6  [{'credit_id': '52fe4981c3a368484e12ee29', 'de...  85446075
#
# [5 rows x 23 columns]

# %%
english_movies.shape
# Out:
# (2575, 23)

# %%
non_english_movies = df[df['original_language'] != 'en']
non_english_movies.head()
# Out:
#     id belongs_to_collection    budget  \
# 3    4                   NaN   1200000
# 4    5                   NaN         0
# 15  16                   NaN    500000
# 30  31                   NaN  13000000
# 31  32                   NaN         0
#
#                                                genres  \
# 3   [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4   [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 15  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 30  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 31  [{'id': 9648, 'name': 'Mystery'}, {'id': 18, '...
#
#                                  homepage    imdb_id original_language  \
# 3              http://kahaanithefilm.com/  tt1821480                hi
# 4                                     NaN  tt1380152                ko
# 15  http://skinningmovie.com/synopsis.htm  tt1129437                sr
# 30                                    NaN  tt1675434                fr
# 31            http://www.cache-derfilm.at  tt0387898                fr
#
#    original_title                                           overview  \
# 3         Kahaani  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...
# 4            마린보이  Marine Boy is the story of a former national s...
# 15        Šišanje  Novica is a mathematics champion in a Belgrade...
# 30   Intouchables  A true story of two men who should never have ...
# 31          Caché  A married couple is terrorized by a series of ...
#
#     popularity  ... release_date runtime  \
# 3     3.174936  ...       3/9/12   122.0
# 4     1.148070  ...       2/5/09   118.0
# 15    1.018477  ...      10/6/10    97.0
# 30   16.086919  ...      11/2/11   112.0
# 31    5.695860  ...       5/2/05   117.0
#
#                                      spoken_languages    status  \
# 3   [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4            [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
# 15            [{'iso_639_1': 'sr', 'name': 'Srpski'}]  Released
# 30  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 31          [{'iso_639_1': 'fr', 'name': 'Français'}]  Released
#
#                                               tagline             title  \
# 3                                                 NaN           Kahaani
# 4                                                 NaN        Marine Boy
# 15  Life is sometimes rude game: one mistake can b...          Skinning
# 30  Sometimes you have to reach into someone else'...  The Intouchables
# 31                                                NaN             Caché
#
#                                              Keywords  \
# 3   [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                 NaN
# 15  [{'id': 379, 'name': 'skinhead'}, {'id': 7492,...
# 30  [{'id': 3230, 'name': 'male friendship'}, {'id...
# 31  [{'id': 90, 'name': 'paris'}, {'id': 213, 'nam...
#
#                                                  cast  \
# 3   [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4   [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# 15  [{'cast_id': 1001, 'character': 'Novica', 'cre...
# 30  [{'cast_id': 6, 'character': 'Philippe', 'cred...
# 31  [{'cast_id': 2, 'character': 'Georges Laurent'...
#
#                                                  crew    revenue
# 3   [{'credit_id': '52fe48779251416c9108d6eb', 'de...   16000000
# 4   [{'credit_id': '52fe464b9251416c75073b43', 'de...    3923970
# 15  [{'credit_id': '52fe4927c3a36847f818bb5f', 'de...        198
# 30  [{'credit_id': '52fe4967c3a368484e129b63', 'de...  426480871
# 31  [{'credit_id': '52fe4244c3a36847f8011073', 'de...   36000000
#
# [5 rows x 23 columns]

# %%
non_english_movies.shape
# Out:
# (425, 23)

# %%
long_movies=df[df['runtime']>120]
long_movies[['title','cast']]
# Out:
#                     title                                               cast
# 3                 Kahaani  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 12        American Beauty  [{'cast_id': 6, 'character': 'Lester Burnham',...
# 14        Minority Report  [{'cast_id': 5, 'character': 'Chief John Ander...
# 20          Lost in Space  [{'cast_id': 26, 'character': 'Dr. Zachary Smi...
# 33        ABCs of Death 2  [{'cast_id': 60, 'character': 'Assassin (Segme...
# ...                   ...                                                ...
# 2969         Gosford Park  [{'cast_id': 2, 'character': 'Mrs. Wilson', 'c...
# 2970        The Bodyguard  [{'cast_id': 17, 'character': 'Rachel Marron',...
# 2980     Action Hero Biju  [{'cast_id': 1, 'character': 'Sub-Inspector Bi...
# 2992  The Thief of Bagdad  [{'cast_id': 3, 'character': 'The Thief of Bag...
# 2993         The Terminal  [{'cast_id': 4, 'character': 'Viktor Navorski'...
#
# [657 rows x 2 columns]

# %%
long_movies.shape
# Out:
# (657, 23)

# %%
short_movies=df[df['runtime']<120]
short_movies[['title','cast','original_language']]
# Out:
#                                          title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 4                                   Marine Boy
# 5       Pinocchio and the Emperor of the Night
# ...                                        ...
# 2994                               School Ties
# 2995                                   Chasers
# 2996                          We Are the Best!
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                    cast original_language
# 0     [{'cast_id': 4, 'character': 'Lou', 'credit_id...                en
# 1     [{'cast_id': 1, 'character': 'Mia Thermopolis'...                en
# 2     [{'cast_id': 5, 'character': 'Andrew Neimann',...                en
# 4     [{'cast_id': 3, 'character': 'Chun-soo', 'cred...                ko
# 5     [{'cast_id': 6, 'character': 'Pinocchio (voice...                en
# ...                                                 ...               ...
# 2994  [{'cast_id': 2, 'character': 'David Greene', '...                en
# 2995  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...                en
# 2996  [{'cast_id': 5, 'character': 'Bobo', 'credit_i...                sv
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...                en
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...                en
#
# [2293 rows x 3 columns]

# %%
short_movies.shape
# Out:
# (2293, 23)

# %%
(df['original_language']=='en')& (df['runtime']>120)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2995    False
# 2996    False
# 2997    False
# 2998    False
# 2999    False
# Length: 3000, dtype: bool

# %%
(df['original_language']=='en')| (df['runtime']>120)
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4       False
#         ...
# 2995     True
# 2996    False
# 2997     True
# 2998     True
# 2999     True
# Length: 3000, dtype: bool

# %%
long_english_movies=df[(df['original_language']=='en')& (df['runtime']>120)]

# %%
long_english_movies
# Out:
#         id                              belongs_to_collection     budget  \
# 12      13                                                NaN   15000000
# 14      15                                                NaN  102000000
# 20      21                                                NaN   80000000
# 33      34  [{'id': 207632, 'name': 'The ABCs of Death Col...          0
# 37      38                                                NaN   50000000
# ...    ...                                                ...        ...
# 2967  2968  [{'id': 387219, 'name': 'The Hustler Collectio...    2000000
# 2969  2970                                                NaN   19800000
# 2970  2971                                                NaN   25000000
# 2992  2993                                                NaN    1135654
# 2993  2994                                                NaN   60000000
#
#                                                  genres  \
# 12                        [{'id': 18, 'name': 'Drama'}]
# 14    [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 20    [{'id': 12, 'name': 'Adventure'}, {'id': 10751...
# 33                       [{'id': 27, 'name': 'Horror'}]
# 37    [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# ...                                                 ...
# 2967                      [{'id': 18, 'name': 'Drama'}]
# 2969  [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'na...
# 2970  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# 2992  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2993  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
#
#                                   homepage    imdb_id original_language  \
# 12           http://www.dreamworks.com/ab/  tt0169547                en
# 14                                     NaN  tt0181689                en
# 20                                     NaN  tt0120738                en
# 33                                     NaN  tt2926810                en
# 37                                     NaN  tt0114069                en
# ...                                    ...        ...               ...
# 2967                                   NaN  tt0054997                en
# 2969                                   NaN  tt0280707                en
# 2970                                   NaN  tt0103855                en
# 2992                                   NaN  tt0015400                en
# 2993  http://www.theterminal-themovie.com/  tt0362227                en
#
#            original_title                                           overview  \
# 12        American Beauty  Lester Burnham, a depressed suburban father in...
# 14        Minority Report  John Anderton is a top 'Precrime' cop in the l...
# 20          Lost in Space  The prospects for continuing life on Earth in ...
# 33        ABCs of Death 2  Taking all that was great from the first insta...
# 37               Outbreak  A deadly airborne virus finds its way into the...
# ...                   ...                                                ...
# 2967          The Hustler  Fast Eddie Felson is a small-time pool hustler...
# 2969         Gosford Park  Multiple storylined drama set in 1932, showing...
# 2970        The Bodyguard  A former Secret Service agent grudgingly takes...
# 2992  The Thief of Bagdad  A recalcitrant thief vies with a duplicitous M...
# 2993         The Terminal  Viktor Navorski is a man without a country; hi...
#
#       popularity  ... release_date runtime  \
# 12     20.726578  ...      9/15/99   122.0
# 14     20.666063  ...      6/20/02   145.0
# 20     12.000579  ...       4/3/98   130.0
# 33      8.254856  ...      10/2/14   125.0
# 37     13.676444  ...      3/10/95   127.0
# ...          ...  ...          ...     ...
# 2967    9.333533  ...      9/25/61   134.0
# 2969   14.101101  ...      11/7/01   137.0
# 2970    9.805017  ...     11/25/92   129.0
# 2992    3.878515  ...      3/18/24   149.0
# 2993   14.092373  ...      6/17/04   128.0
#
#                                        spoken_languages    status  \
# 12             [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 14    [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 20             [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 33    [{'iso_639_1': 'ar', 'name': 'العربية'}, {'iso...  Released
# 37    [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# ...                                                 ...       ...
# 2967           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2969           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2970           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2992       [{'iso_639_1': 'xx', 'name': 'No Language'}]  Released
# 2993  [{'iso_639_1': 'bg', 'name': 'български език'}...  Released
#
#                                                 tagline                title  \
# 12                                         Look closer.      American Beauty
# 14      The system is perfect until it comes after you.      Minority Report
# 20                               Danger, Will Robinson!        Lost in Space
# 33                              Some people never learn      ABCs of Death 2
# 37    This animal carries a deadly virus... and the ...             Outbreak
# ...                                                 ...                  ...
# 2967  They called him Fast Eddie. He was a winner. H...          The Hustler
# 2969  Tea at four. Dinner at eight. Murder at midnight.         Gosford Park
# 2970  Never let her out of your sight. Never let you...        The Bodyguard
# 2992                         "Happiness Must Be Earned"  The Thief of Bagdad
# 2993                                   Life is waiting.         The Terminal
#
#                                                Keywords  \
# 12    [{'id': 255, 'name': 'male nudity'}, {'id': 29...
# 14    [{'id': 476, 'name': 'self-fulfilling prophecy...
# 20    [{'id': 4379, 'name': 'time travel'}, {'id': 1...
# 33    [{'id': 9706, 'name': 'anthology'}, {'id': 187...
# 37    [{'id': 1261, 'name': 'river'}, {'id': 1402, '...
# ...                                                 ...
# 2967  [{'id': 236, 'name': 'suicide'}, {'id': 395, '...
# 2969  [{'id': 964, 'name': 'servant'}, {'id': 10594,...
# 2970  [{'id': 1156, 'name': 'sister sister relations...
# 2992  [{'id': 255, 'name': 'male nudity'}, {'id': 14...
# 2993  [{'id': 242, 'name': 'new york'}, {'id': 822, ...
#
#                                                    cast  \
# 12    [{'cast_id': 6, 'character': 'Lester Burnham',...
# 14    [{'cast_id': 5, 'character': 'Chief John Ander...
# 20    [{'cast_id': 26, 'character': 'Dr. Zachary Smi...
# 33    [{'cast_id': 60, 'character': 'Assassin (Segme...
# 37    [{'cast_id': 1, 'character': 'Sam Daniels', 'c...
# ...                                                 ...
# 2967  [{'cast_id': 15, 'character': 'Eddie Felson', ...
# 2969  [{'cast_id': 2, 'character': 'Mrs. Wilson', 'c...
# 2970  [{'cast_id': 17, 'character': 'Rachel Marron',...
# 2992  [{'cast_id': 3, 'character': 'The Thief of Bag...
# 2993  [{'cast_id': 4, 'character': 'Viktor Navorski'...
#
#                                                    crew    revenue
# 12    [{'credit_id': '52fe420ec3a36847f80007c5', 'de...  356296601
# 14    [{'credit_id': '52fe4223c3a36847f8006f3d', 'de...  358372926
# 20    [{'credit_id': '52fe433bc3a36847f80448b9', 'de...  136159423
# 33    [{'credit_id': '52fe4cd69251416c91101d73', 'de...       7171
# 37    [{'credit_id': '52fe446ac3a36847f80949d3', 'de...  189859560
# ...                                                 ...        ...
# 2967  [{'credit_id': '52fe4297c3a36847f802a989', 'de...    7600000
# 2969  [{'credit_id': '52fe4401c3a36847f807ceab', 'de...   87754044
# 2970  [{'credit_id': '52fe425ec3a36847f8019133', 'de...  411006740
# 2992  [{'credit_id': '52fe45bec3a368484e06c70b', 'de...    1213880
# 2993  [{'credit_id': '52fe4259c3a36847f8017699', 'de...  219417255
#
# [506 rows x 23 columns]

# %%
long_english_movies.shape
# Out:
# (506, 23)

# %%
df.shape
# Out:
# (3000, 23)

# %%
df['runtime']
# Out:
# 0        93.0
# 1       113.0
# 2       105.0
# 3       122.0
# 4       118.0
#         ...
# 2995    102.0
# 2996    102.0
# 2997    120.0
# 2998     90.0
# 2999    106.0
# Name: runtime, Length: 3000, dtype: float64

# %%
#Add new column which is just half the runtime

df['half_runtime']=df['runtime']*0.5

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  ... runtime  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...    93.0
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...   113.0
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...   105.0
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...   122.0
# 4  Marine Boy is the story of a former national s...    1.148070  ...   118.0
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
#
#                                              tagline  \
# 0  The Laws of Space and Time are About to be Vio...
# 1  It can take a lifetime to find true love; she'...
# 2    The road to greatness can take you to the edge.
# 3                                                NaN
# 4                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue half_runtime
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651         46.5
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435         56.5
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000         52.5
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000         61.0
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970         59.0
#
# [5 rows x 24 columns]

# %%
#Creating another new column by subtracting/adding two existing columns

df['movie_profit'] = df['revenue']-df['budget']

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
#
#                                              tagline  \
# 0  The Laws of Space and Time are About to be Vio...
# 1  It can take a lifetime to find true love; she'...
# 2    The road to greatness can take you to the edge.
# 3                                                NaN
# 4                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                NaN
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4  [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
#
#                                                 crew   revenue half_runtime  \
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651         46.5
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435         56.5
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000         52.5
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000         61.0
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970         59.0
#
#   movie_profit
# 0     -1685349
# 1     55149435
# 2      9792000
# 3     14800000
# 4      3923970
#
# [5 rows x 25 columns]

# %%
df.tail(10)
# Out:
#         id                              belongs_to_collection    budget  \
# 2990  2991                                                NaN         0
# 2991  2992  [{'id': 107469, 'name': 'Save The Last Dance C...  13000000
# 2992  2993                                                NaN   1135654
# 2993  2994                                                NaN  60000000
# 2994  2995                                                NaN         0
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# 2990  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 2991  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 2992  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2993  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2994                      [{'id': 18, 'name': 'Drama'}]
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                   homepage    imdb_id original_language  \
# 2990                                   NaN  tt0118663                en
# 2991                                   NaN  tt0206275                en
# 2992                                   NaN  tt0015400                en
# 2993  http://www.theterminal-themovie.com/  tt0362227                en
# 2994                                   NaN  tt0105327                en
# 2995                                   NaN  tt0109403                en
# 2996                                   NaN  tt2364975                sv
# 2997                                   NaN  tt0116908                en
# 2998        http://www.alongcamepolly.com/  tt0343135                en
# 2999      http://www.abductionthefilm.com/  tt1600195                en
#
#                original_title  \
# 2990                 B.A.P.S.
# 2991      Save the Last Dance
# 2992      The Thief of Bagdad
# 2993             The Terminal
# 2994              School Ties
# 2995                  Chasers
# 2996              Vi är bäst!
# 2997  The Long Kiss Goodnight
# 2998         Along Came Polly
# 2999                Abduction
#
#                                                overview  popularity  ...  \
# 2990  Can two clueless Georgia homegirls with big he...    1.560980  ...
# 2991  A white midwestern girl moves to Chicago, wher...    4.794088  ...
# 2992  A recalcitrant thief vies with a duplicitous M...    3.878515  ...
# 2993  Viktor Navorski is a man without a country; hi...   14.092373  ...
# 2994  When David Greene receives a football scholars...    7.438381  ...
# 2995  Military men Rock Reilly and Eddie Devane are ...    9.853270  ...
# 2996  Three girls in 1980s Stockholm decide to form ...    3.727996  ...
# 2997  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
# 2998  Reuben Feffer is a guy who's spent his entire ...   15.725542  ...
# 2999  A young man sets out to uncover the truth abou...   10.512109  ...
#
#                                        spoken_languages    status  \
# 2990           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2991           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2992       [{'iso_639_1': 'xx', 'name': 'No Language'}]  Released
# 2993  [{'iso_639_1': 'bg', 'name': 'български език'}...  Released
# 2994           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2995           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2996           [{'iso_639_1': 'sv', 'name': 'svenska'}]  Released
# 2997           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2998           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2999           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                 tagline  \
# 2990                These Pretty Women... Are Clueless!
# 2991        The Only Person You Need To Be Is Yourself.
# 2992                         "Happiness Must Be Earned"
# 2993                                   Life is waiting.
# 2994  Just because you’re accepted doesn’t mean you ...
# 2995  It was supposed to be a routine prisoner trans...
# 2996                                                NaN
# 2997               What's forgotten is not always gone.
# 2998  For the most cautious man on Earth, life is ab...
# 2999          They stole his life. He's taking it back.
#
#                         title  \
# 2990                 B.A.P.S.
# 2991      Save the Last Dance
# 2992      The Thief of Bagdad
# 2993             The Terminal
# 2994              School Ties
# 2995                  Chasers
# 2996         We Are the Best!
# 2997  The Long Kiss Goodnight
# 2998         Along Came Polly
# 2999                Abduction
#
#                                                Keywords  \
# 2990  [{'id': 1437, 'name': 'burglar'}, {'id': 1946,...
# 2991  [{'id': 4118, 'name': 'ballet dancer'}, {'id':...
# 2992  [{'id': 255, 'name': 'male nudity'}, {'id': 14...
# 2993  [{'id': 242, 'name': 'new york'}, {'id': 822, ...
# 2994  [{'id': 6075, 'name': 'sport'}, {'id': 10144, ...
# 2995  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 2996  [{'id': 1192, 'name': 'sweden'}, {'id': 4470, ...
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#                                                    cast  \
# 2990  [{'cast_id': 3, 'character': 'Nisi', 'credit_i...
# 2991  [{'cast_id': 18, 'character': 'Sara Johnson', ...
# 2992  [{'cast_id': 3, 'character': 'The Thief of Bag...
# 2993  [{'cast_id': 4, 'character': 'Viktor Navorski'...
# 2994  [{'cast_id': 2, 'character': 'David Greene', '...
# 2995  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2996  [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# 2997  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew    revenue  \
# 2990  [{'credit_id': '52fe477b9251416c7509af57', 'de...    7240837
# 2991  [{'credit_id': '52fe4533c3a36847f80c1c6b', 'de...   91038276
# 2992  [{'credit_id': '52fe45bec3a368484e06c70b', 'de...    1213880
# 2993  [{'credit_id': '52fe4259c3a36847f8017699', 'de...  219417255
# 2994  [{'credit_id': '5637777ac3a3681b4d01f9f5', 'de...   14715067
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687
# 2996  [{'credit_id': '5716b72ac3a3686678012c84', 'de...     180590
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155
#
#      half_runtime movie_profit
# 2990         45.0      7240837
# 2991         56.0     78038276
# 2992         74.5        78226
# 2993         64.0    159417255
# 2994         53.0     14715067
# 2995         51.0      1596687
# 2996         51.0       180590
# 2997         60.0     24456761
# 2998         45.0    129963386
# 2999         53.0     47087155
#
# [10 rows x 25 columns]

# %%
#remove Column

df.drop(['cast'],axis=1,inplace=False)
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# 0                        [{'id': 35, 'name': 'Comedy'}]
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                         [{'id': 18, 'name': 'Drama'}]
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# ...                                                 ...
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                homepage    imdb_id original_language  \
# 0                                   NaN  tt2637294                en
# 1                                   NaN  tt0368933                en
# 2     http://sonyclassics.com/whiplash/  tt2582802                en
# 3            http://kahaanithefilm.com/  tt1821480                hi
# 4                                   NaN  tt1380152                ko
# ...                                 ...        ...               ...
# 2995                                NaN  tt0109403                en
# 2996                                NaN  tt2364975                sv
# 2997                                NaN  tt0116908                en
# 2998     http://www.alongcamepolly.com/  tt0343135                en
# 2999   http://www.abductionthefilm.com/  tt1600195                en
#
#                                 original_title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                         마린보이
# ...                                        ...
# 2995                                   Chasers
# 2996                               Vi är bäst!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                overview  popularity  ...  \
# 0     When Lou, who has become the "father of the In...    6.575393  ...
# 1     Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2     Under the direction of a ruthless instructor, ...   64.299990  ...
# 3     Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4     Marine Boy is the story of a former national s...    1.148070  ...
# ...                                                 ...         ...  ...
# 2995  Military men Rock Reilly and Eddie Devane are ...    9.853270  ...
# 2996  Three girls in 1980s Stockholm decide to form ...    3.727996  ...
# 2997  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
# 2998  Reuben Feffer is a guy who's spent his entire ...   15.725542  ...
# 2999  A young man sets out to uncover the truth abou...   10.512109  ...
#
#      runtime                                   spoken_languages    status  \
# 0       93.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1      113.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2      105.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3      122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4      118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
# ...      ...                                                ...       ...
# 2995   102.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2996   102.0           [{'iso_639_1': 'sv', 'name': 'svenska'}]  Released
# 2997   120.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2998    90.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2999   106.0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                 tagline  \
# 0     The Laws of Space and Time are About to be Vio...
# 1     It can take a lifetime to find true love; she'...
# 2       The road to greatness can take you to the edge.
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2995  It was supposed to be a routine prisoner trans...
# 2996                                                NaN
# 2997               What's forgotten is not always gone.
# 2998  For the most cautious man on Earth, life is ab...
# 2999          They stole his life. He's taking it back.
#
#                                          title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                   Marine Boy
# ...                                        ...
# 2995                                   Chasers
# 2996                          We Are the Best!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                Keywords  \
# 0     [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1     [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2     [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3     [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                   NaN
# ...                                                 ...
# 2995  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 2996  [{'id': 1192, 'name': 'sweden'}, {'id': 4470, ...
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#                                                    crew    revenue  \
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...   12314651
# 1     [{'credit_id': '52fe43fe9251416c7502563d', 'de...   95149435
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...   13092000
# 3     [{'credit_id': '52fe48779251416c9108d6eb', 'de...   16000000
# 4     [{'credit_id': '52fe464b9251416c75073b43', 'de...    3923970
# ...                                                 ...        ...
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687
# 2996  [{'credit_id': '5716b72ac3a3686678012c84', 'de...     180590
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155
#
#      half_runtime movie_profit
# 0            46.5     -1685349
# 1            56.5     55149435
# 2            52.5      9792000
# 3            61.0     14800000
# 4            59.0      3923970
# ...           ...          ...
# 2995         51.0      1596687
# 2996         51.0       180590
# 2997         60.0     24456761
# 2998         45.0    129963386
# 2999         53.0     47087155
#
# [3000 rows x 24 columns]

# %%
df['cast']=df.index+1

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
#
#                                              tagline  \
# 0  The Laws of Space and Time are About to be Vio...
# 1  It can take a lifetime to find true love; she'...
# 2    The road to greatness can take you to the edge.
# 3                                                NaN
# 4                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords cast  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...    1
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...    2
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...    3
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...    4
# 4                                                NaN    5
#
#                                                 crew   revenue half_runtime  \
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651         46.5
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435         56.5
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000         52.5
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000         61.0
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970         59.0
#
#   movie_profit
# 0     -1685349
# 1     55149435
# 2      9792000
# 3     14800000
# 4      3923970
#
# [5 rows x 25 columns]

# %%
df['id'] = df.index+1

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
#
#                                              tagline  \
# 0  The Laws of Space and Time are About to be Vio...
# 1  It can take a lifetime to find true love; she'...
# 2    The road to greatness can take you to the edge.
# 3                                                NaN
# 4                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords cast  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...    1
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...    2
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...    3
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...    4
# 4                                                NaN    5
#
#                                                 crew   revenue half_runtime  \
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651         46.5
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435         56.5
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000         52.5
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000         61.0
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970         59.0
#
#   movie_profit
# 0     -1685349
# 1     55149435
# 2      9792000
# 3     14800000
# 4      3923970
#
# [5 rows x 25 columns]

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                                NaN  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
#
#                                     spoken_languages    status  \
# 0           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
#
#                                              tagline  \
# 0  The Laws of Space and Time are About to be Vio...
# 1  It can take a lifetime to find true love; she'...
# 2    The road to greatness can take you to the edge.
# 3                                                NaN
# 4                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords cast  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...    1
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...    2
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...    3
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...    4
# 4                                                NaN    5
#
#                                                 crew   revenue half_runtime  \
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651         46.5
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435         56.5
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000         52.5
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000         61.0
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970         59.0
#
#   movie_profit
# 0     -1685349
# 1     55149435
# 2      9792000
# 3     14800000
# 4      3923970
#
# [5 rows x 25 columns]

# %%
df['budget'].sum()
# Out:
# 67594002330

# %%
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# 0                        [{'id': 35, 'name': 'Comedy'}]
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                         [{'id': 18, 'name': 'Drama'}]
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# ...                                                 ...
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                homepage    imdb_id original_language  \
# 0                                   NaN  tt2637294                en
# 1                                   NaN  tt0368933                en
# 2     http://sonyclassics.com/whiplash/  tt2582802                en
# 3            http://kahaanithefilm.com/  tt1821480                hi
# 4                                   NaN  tt1380152                ko
# ...                                 ...        ...               ...
# 2995                                NaN  tt0109403                en
# 2996                                NaN  tt2364975                sv
# 2997                                NaN  tt0116908                en
# 2998     http://www.alongcamepolly.com/  tt0343135                en
# 2999   http://www.abductionthefilm.com/  tt1600195                en
#
#                                 original_title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                         마린보이
# ...                                        ...
# 2995                                   Chasers
# 2996                               Vi är bäst!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                overview  popularity  ...  \
# 0     When Lou, who has become the "father of the In...    6.575393  ...
# 1     Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2     Under the direction of a ruthless instructor, ...   64.299990  ...
# 3     Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4     Marine Boy is the story of a former national s...    1.148070  ...
# ...                                                 ...         ...  ...
# 2995  Military men Rock Reilly and Eddie Devane are ...    9.853270  ...
# 2996  Three girls in 1980s Stockholm decide to form ...    3.727996  ...
# 2997  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
# 2998  Reuben Feffer is a guy who's spent his entire ...   15.725542  ...
# 2999  A young man sets out to uncover the truth abou...   10.512109  ...
#
#                                        spoken_languages    status  \
# 0              [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1              [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2              [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3     [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4              [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
# ...                                                 ...       ...
# 2995           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2996           [{'iso_639_1': 'sv', 'name': 'svenska'}]  Released
# 2997           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2998           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2999           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                 tagline  \
# 0     The Laws of Space and Time are About to be Vio...
# 1     It can take a lifetime to find true love; she'...
# 2       The road to greatness can take you to the edge.
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2995  It was supposed to be a routine prisoner trans...
# 2996                                                NaN
# 2997               What's forgotten is not always gone.
# 2998  For the most cautious man on Earth, life is ab...
# 2999          They stole his life. He's taking it back.
#
#                                          title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                   Marine Boy
# ...                                        ...
# 2995                                   Chasers
# 2996                          We Are the Best!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                Keywords  cast  \
# 0     [{'id': 4379, 'name': 'time travel'}, {'id': 9...     1
# 1     [{'id': 2505, 'name': 'coronation'}, {'id': 42...     2
# 2     [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...     3
# 3     [{'id': 10092, 'name': 'mystery'}, {'id': 1054...     4
# 4                                                   NaN     5
# ...                                                 ...   ...
# 2995  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...  2996
# 2996  [{'id': 1192, 'name': 'sweden'}, {'id': 4470, ...  2997
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...  2998
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...  2999
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...  3000
#
#                                                    crew    revenue  \
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...   12314651
# 1     [{'credit_id': '52fe43fe9251416c7502563d', 'de...   95149435
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...   13092000
# 3     [{'credit_id': '52fe48779251416c9108d6eb', 'de...   16000000
# 4     [{'credit_id': '52fe464b9251416c75073b43', 'de...    3923970
# ...                                                 ...        ...
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687
# 2996  [{'credit_id': '5716b72ac3a3686678012c84', 'de...     180590
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155
#
#      half_runtime movie_profit
# 0            46.5     -1685349
# 1            56.5     55149435
# 2            52.5      9792000
# 3            61.0     14800000
# 4            59.0      3923970
# ...           ...          ...
# 2995         51.0      1596687
# 2996         51.0       180590
# 2997         60.0     24456761
# 2998         45.0    129963386
# 2999         53.0     47087155
#
# [3000 rows x 25 columns]

# %%
df.loc[:3,'revenue']=np.nan

# %%
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# 0                        [{'id': 35, 'name': 'Comedy'}]
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                         [{'id': 18, 'name': 'Drama'}]
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# ...                                                 ...
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                homepage    imdb_id original_language  \
# 0                                   NaN  tt2637294                en
# 1                                   NaN  tt0368933                en
# 2     http://sonyclassics.com/whiplash/  tt2582802                en
# 3            http://kahaanithefilm.com/  tt1821480                hi
# 4                                   NaN  tt1380152                ko
# ...                                 ...        ...               ...
# 2995                                NaN  tt0109403                en
# 2996                                NaN  tt2364975                sv
# 2997                                NaN  tt0116908                en
# 2998     http://www.alongcamepolly.com/  tt0343135                en
# 2999   http://www.abductionthefilm.com/  tt1600195                en
#
#                                 original_title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                         마린보이
# ...                                        ...
# 2995                                   Chasers
# 2996                               Vi är bäst!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                overview  popularity  ...  \
# 0     When Lou, who has become the "father of the In...    6.575393  ...
# 1     Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2     Under the direction of a ruthless instructor, ...   64.299990  ...
# 3     Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4     Marine Boy is the story of a former national s...    1.148070  ...
# ...                                                 ...         ...  ...
# 2995  Military men Rock Reilly and Eddie Devane are ...    9.853270  ...
# 2996  Three girls in 1980s Stockholm decide to form ...    3.727996  ...
# 2997  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
# 2998  Reuben Feffer is a guy who's spent his entire ...   15.725542  ...
# 2999  A young man sets out to uncover the truth abou...   10.512109  ...
#
#                                        spoken_languages    status  \
# 0              [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1              [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2              [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 3     [{'iso_639_1': 'en', 'name': 'English'}, {'iso...  Released
# 4              [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]  Released
# ...                                                 ...       ...
# 2995           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2996           [{'iso_639_1': 'sv', 'name': 'svenska'}]  Released
# 2997           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2998           [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2999           [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                 tagline  \
# 0     The Laws of Space and Time are About to be Vio...
# 1     It can take a lifetime to find true love; she'...
# 2       The road to greatness can take you to the edge.
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2995  It was supposed to be a routine prisoner trans...
# 2996                                                NaN
# 2997               What's forgotten is not always gone.
# 2998  For the most cautious man on Earth, life is ab...
# 2999          They stole his life. He's taking it back.
#
#                                          title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                   Marine Boy
# ...                                        ...
# 2995                                   Chasers
# 2996                          We Are the Best!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                Keywords  cast  \
# 0     [{'id': 4379, 'name': 'time travel'}, {'id': 9...     1
# 1     [{'id': 2505, 'name': 'coronation'}, {'id': 42...     2
# 2     [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...     3
# 3     [{'id': 10092, 'name': 'mystery'}, {'id': 1054...     4
# 4                                                   NaN     5
# ...                                                 ...   ...
# 2995  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...  2996
# 2996  [{'id': 1192, 'name': 'sweden'}, {'id': 4470, ...  2997
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...  2998
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...  2999
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...  3000
#
#                                                    crew      revenue  \
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...          NaN
# 1     [{'credit_id': '52fe43fe9251416c7502563d', 'de...          NaN
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...          NaN
# 3     [{'credit_id': '52fe48779251416c9108d6eb', 'de...          NaN
# 4     [{'credit_id': '52fe464b9251416c75073b43', 'de...    3923970.0
# ...                                                 ...          ...
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687.0
# 2996  [{'credit_id': '5716b72ac3a3686678012c84', 'de...     180590.0
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761.0
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386.0
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155.0
#
#      half_runtime movie_profit
# 0            46.5     -1685349
# 1            56.5     55149435
# 2            52.5      9792000
# 3            61.0     14800000
# 4            59.0      3923970
# ...           ...          ...
# 2995         51.0      1596687
# 2996         51.0       180590
# 2997         60.0     24456761
# 2998         45.0    129963386
# 2999         53.0     47087155
#
# [3000 rows x 25 columns]

# %%
def uppercase(column):
    return column.upper()

# %%
df['capitalised title'] = df['title'].apply(uppercase)

# %%
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# 0                        [{'id': 35, 'name': 'Comedy'}]
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                         [{'id': 18, 'name': 'Drama'}]
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# ...                                                 ...
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                homepage    imdb_id original_language  \
# 0                                   NaN  tt2637294                en
# 1                                   NaN  tt0368933                en
# 2     http://sonyclassics.com/whiplash/  tt2582802                en
# 3            http://kahaanithefilm.com/  tt1821480                hi
# 4                                   NaN  tt1380152                ko
# ...                                 ...        ...               ...
# 2995                                NaN  tt0109403                en
# 2996                                NaN  tt2364975                sv
# 2997                                NaN  tt0116908                en
# 2998     http://www.alongcamepolly.com/  tt0343135                en
# 2999   http://www.abductionthefilm.com/  tt1600195                en
#
#                                 original_title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                         마린보이
# ...                                        ...
# 2995                                   Chasers
# 2996                               Vi är bäst!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                overview  popularity  ...  \
# 0     When Lou, who has become the "father of the In...    6.575393  ...
# 1     Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2     Under the direction of a ruthless instructor, ...   64.299990  ...
# 3     Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4     Marine Boy is the story of a former national s...    1.148070  ...
# ...                                                 ...         ...  ...
# 2995  Military men Rock Reilly and Eddie Devane are ...    9.853270  ...
# 2996  Three girls in 1980s Stockholm decide to form ...    3.727996  ...
# 2997  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
# 2998  Reuben Feffer is a guy who's spent his entire ...   15.725542  ...
# 2999  A young man sets out to uncover the truth abou...   10.512109  ...
#
#         status                                            tagline  \
# 0     Released  The Laws of Space and Time are About to be Vio...
# 1     Released  It can take a lifetime to find true love; she'...
# 2     Released    The road to greatness can take you to the edge.
# 3     Released                                                NaN
# 4     Released                                                NaN
# ...        ...                                                ...
# 2995  Released  It was supposed to be a routine prisoner trans...
# 2996  Released                                                NaN
# 2997  Released               What's forgotten is not always gone.
# 2998  Released  For the most cautious man on Earth, life is ab...
# 2999  Released          They stole his life. He's taking it back.
#
#                                          title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                   Marine Boy
# ...                                        ...
# 2995                                   Chasers
# 2996                          We Are the Best!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                Keywords  cast  \
# 0     [{'id': 4379, 'name': 'time travel'}, {'id': 9...     1
# 1     [{'id': 2505, 'name': 'coronation'}, {'id': 42...     2
# 2     [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...     3
# 3     [{'id': 10092, 'name': 'mystery'}, {'id': 1054...     4
# 4                                                   NaN     5
# ...                                                 ...   ...
# 2995  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...  2996
# 2996  [{'id': 1192, 'name': 'sweden'}, {'id': 4470, ...  2997
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...  2998
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...  2999
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...  3000
#
#                                                    crew      revenue  \
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...          NaN
# 1     [{'credit_id': '52fe43fe9251416c7502563d', 'de...          NaN
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...          NaN
# 3     [{'credit_id': '52fe48779251416c9108d6eb', 'de...          NaN
# 4     [{'credit_id': '52fe464b9251416c75073b43', 'de...    3923970.0
# ...                                                 ...          ...
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687.0
# 2996  [{'credit_id': '5716b72ac3a3686678012c84', 'de...     180590.0
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761.0
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386.0
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155.0
#
#      half_runtime movie_profit                         capitalised title
# 0            46.5     -1685349                    HOT TUB TIME MACHINE 2
# 1            56.5     55149435  THE PRINCESS DIARIES 2: ROYAL ENGAGEMENT
# 2            52.5      9792000                                  WHIPLASH
# 3            61.0     14800000                                   KAHAANI
# 4            59.0      3923970                                MARINE BOY
# ...           ...          ...                                       ...
# 2995         51.0      1596687                                   CHASERS
# 2996         51.0       180590                          WE ARE THE BEST!
# 2997         60.0     24456761                   THE LONG KISS GOODNIGHT
# 2998         45.0    129963386                          ALONG CAME POLLY
# 2999         53.0     47087155                                 ABDUCTION
#
# [3000 rows x 26 columns]

# %%
def Lowercasse(column):
    return column.lower()

# %%
df['capitalised title'] = df['title'].apply(Lowercasse)

# %%
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# 0                        [{'id': 35, 'name': 'Comedy'}]
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                         [{'id': 18, 'name': 'Drama'}]
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# ...                                                 ...
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                homepage    imdb_id original_language  \
# 0                                   NaN  tt2637294                en
# 1                                   NaN  tt0368933                en
# 2     http://sonyclassics.com/whiplash/  tt2582802                en
# 3            http://kahaanithefilm.com/  tt1821480                hi
# 4                                   NaN  tt1380152                ko
# ...                                 ...        ...               ...
# 2995                                NaN  tt0109403                en
# 2996                                NaN  tt2364975                sv
# 2997                                NaN  tt0116908                en
# 2998     http://www.alongcamepolly.com/  tt0343135                en
# 2999   http://www.abductionthefilm.com/  tt1600195                en
#
#                                 original_title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                         마린보이
# ...                                        ...
# 2995                                   Chasers
# 2996                               Vi är bäst!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                overview  popularity  ...  \
# 0     When Lou, who has become the "father of the In...    6.575393  ...
# 1     Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2     Under the direction of a ruthless instructor, ...   64.299990  ...
# 3     Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4     Marine Boy is the story of a former national s...    1.148070  ...
# ...                                                 ...         ...  ...
# 2995  Military men Rock Reilly and Eddie Devane are ...    9.853270  ...
# 2996  Three girls in 1980s Stockholm decide to form ...    3.727996  ...
# 2997  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
# 2998  Reuben Feffer is a guy who's spent his entire ...   15.725542  ...
# 2999  A young man sets out to uncover the truth abou...   10.512109  ...
#
#         status                                            tagline  \
# 0     Released  The Laws of Space and Time are About to be Vio...
# 1     Released  It can take a lifetime to find true love; she'...
# 2     Released    The road to greatness can take you to the edge.
# 3     Released                                                NaN
# 4     Released                                                NaN
# ...        ...                                                ...
# 2995  Released  It was supposed to be a routine prisoner trans...
# 2996  Released                                                NaN
# 2997  Released               What's forgotten is not always gone.
# 2998  Released  For the most cautious man on Earth, life is ab...
# 2999  Released          They stole his life. He's taking it back.
#
#                                          title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                   Marine Boy
# ...                                        ...
# 2995                                   Chasers
# 2996                          We Are the Best!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                Keywords  cast  \
# 0     [{'id': 4379, 'name': 'time travel'}, {'id': 9...     1
# 1     [{'id': 2505, 'name': 'coronation'}, {'id': 42...     2
# 2     [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...     3
# 3     [{'id': 10092, 'name': 'mystery'}, {'id': 1054...     4
# 4                                                   NaN     5
# ...                                                 ...   ...
# 2995  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...  2996
# 2996  [{'id': 1192, 'name': 'sweden'}, {'id': 4470, ...  2997
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...  2998
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...  2999
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...  3000
#
#                                                    crew      revenue  \
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...          NaN
# 1     [{'credit_id': '52fe43fe9251416c7502563d', 'de...          NaN
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...          NaN
# 3     [{'credit_id': '52fe48779251416c9108d6eb', 'de...          NaN
# 4     [{'credit_id': '52fe464b9251416c75073b43', 'de...    3923970.0
# ...                                                 ...          ...
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687.0
# 2996  [{'credit_id': '5716b72ac3a3686678012c84', 'de...     180590.0
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761.0
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386.0
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155.0
#
#      half_runtime movie_profit                         capitalised title
# 0            46.5     -1685349                    hot tub time machine 2
# 1            56.5     55149435  the princess diaries 2: royal engagement
# 2            52.5      9792000                                  whiplash
# 3            61.0     14800000                                   kahaani
# 4            59.0      3923970                                marine boy
# ...           ...          ...                                       ...
# 2995         51.0      1596687                                   chasers
# 2996         51.0       180590                          we are the best!
# 2997         60.0     24456761                   the long kiss goodnight
# 2998         45.0    129963386                          along came polly
# 2999         53.0     47087155                                 abduction
#
# [3000 rows x 26 columns]

# %%
def revised_profit(revenue,budget):
    if revenue >0:
        new_profit = revenue - budget
    else:
        new_profit = np.nan
    return new_profit

# %%
df['new_profit']=df.apply(lambda x : revised_profit (x.revenue,x.budget),axis=1)

# %%
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# 0                        [{'id': 35, 'name': 'Comedy'}]
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                         [{'id': 18, 'name': 'Drama'}]
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# ...                                                 ...
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                homepage    imdb_id original_language  \
# 0                                   NaN  tt2637294                en
# 1                                   NaN  tt0368933                en
# 2     http://sonyclassics.com/whiplash/  tt2582802                en
# 3            http://kahaanithefilm.com/  tt1821480                hi
# 4                                   NaN  tt1380152                ko
# ...                                 ...        ...               ...
# 2995                                NaN  tt0109403                en
# 2996                                NaN  tt2364975                sv
# 2997                                NaN  tt0116908                en
# 2998     http://www.alongcamepolly.com/  tt0343135                en
# 2999   http://www.abductionthefilm.com/  tt1600195                en
#
#                                 original_title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                         마린보이
# ...                                        ...
# 2995                                   Chasers
# 2996                               Vi är bäst!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                overview  popularity  ...  \
# 0     When Lou, who has become the "father of the In...    6.575393  ...
# 1     Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2     Under the direction of a ruthless instructor, ...   64.299990  ...
# 3     Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4     Marine Boy is the story of a former national s...    1.148070  ...
# ...                                                 ...         ...  ...
# 2995  Military men Rock Reilly and Eddie Devane are ...    9.853270  ...
# 2996  Three girls in 1980s Stockholm decide to form ...    3.727996  ...
# 2997  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
# 2998  Reuben Feffer is a guy who's spent his entire ...   15.725542  ...
# 2999  A young man sets out to uncover the truth abou...   10.512109  ...
#
#                                                 tagline  \
# 0     The Laws of Space and Time are About to be Vio...
# 1     It can take a lifetime to find true love; she'...
# 2       The road to greatness can take you to the edge.
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2995  It was supposed to be a routine prisoner trans...
# 2996                                                NaN
# 2997               What's forgotten is not always gone.
# 2998  For the most cautious man on Earth, life is ab...
# 2999          They stole his life. He's taking it back.
#
#                                          title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                   Marine Boy
# ...                                        ...
# 2995                                   Chasers
# 2996                          We Are the Best!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                Keywords  cast  \
# 0     [{'id': 4379, 'name': 'time travel'}, {'id': 9...     1
# 1     [{'id': 2505, 'name': 'coronation'}, {'id': 42...     2
# 2     [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...     3
# 3     [{'id': 10092, 'name': 'mystery'}, {'id': 1054...     4
# 4                                                   NaN     5
# ...                                                 ...   ...
# 2995  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...  2996
# 2996  [{'id': 1192, 'name': 'sweden'}, {'id': 4470, ...  2997
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...  2998
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...  2999
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...  3000
#
#                                                    crew      revenue  \
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...          NaN
# 1     [{'credit_id': '52fe43fe9251416c7502563d', 'de...          NaN
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...          NaN
# 3     [{'credit_id': '52fe48779251416c9108d6eb', 'de...          NaN
# 4     [{'credit_id': '52fe464b9251416c75073b43', 'de...    3923970.0
# ...                                                 ...          ...
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687.0
# 2996  [{'credit_id': '5716b72ac3a3686678012c84', 'de...     180590.0
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761.0
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386.0
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155.0
#
#      half_runtime movie_profit                         capitalised title  \
# 0            46.5     -1685349                    hot tub time machine 2
# 1            56.5     55149435  the princess diaries 2: royal engagement
# 2            52.5      9792000                                  whiplash
# 3            61.0     14800000                                   kahaani
# 4            59.0      3923970                                marine boy
# ...           ...          ...                                       ...
# 2995         51.0      1596687                                   chasers
# 2996         51.0       180590                          we are the best!
# 2997         60.0     24456761                   the long kiss goodnight
# 2998         45.0    129963386                          along came polly
# 2999         53.0     47087155                                 abduction
#
#        new_profit
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4       3923970.0
# ...           ...
# 2995    1596687.0
# 2996     180590.0
# 2997   24456761.0
# 2998  129963386.0
# 2999   47087155.0
#
# [3000 rows x 27 columns]

# %%
dir(df)
# Out:
# ['Keywords',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__nonzero__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rmatmul__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__round__',
#  '__rpow__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__weakref__',
#  '__xor__',
#  '_accessors',
#  '_accum_func',
#  '_add_numeric_operations',
#  '_agg_by_level',
#  '_agg_examples_doc',
#  '_agg_summary_and_see_also_doc',
#  '_align_frame',
#  '_align_series',
#  '_append',
#  '_arith_method',
#  '_as_manager',
#  '_attrs',
#  '_box_col_values',
#  '_can_fast_transpose',
#  '_check_inplace_and_allows_duplicate_labels',
#  '_check_inplace_setting',
#  '_check_is_chained_assignment_possible',
#  '_check_label_or_level_ambiguity',
#  '_check_setitem_copy',
#  '_clear_item_cache',
#  '_clip_with_one_bound',
#  '_clip_with_scalar',
#  '_cmp_method',
#  '_combine_frame',
#  '_consolidate',
#  '_consolidate_inplace',
#  '_construct_axes_dict',
#  '_construct_axes_from_arguments',
#  '_construct_result',
#  '_constructor',
#  '_constructor_sliced',
#  '_convert',
#  '_count_level',
#  '_data',
#  '_dir_additions',
#  '_dir_deletions',
#  '_dispatch_frame_op',
#  '_drop_axis',
#  '_drop_labels_or_levels',
#  '_ensure_valid_index',
#  '_find_valid_index',
#  '_flags',
#  '_from_arrays',
#  '_from_mgr',
#  '_get_agg_axis',
#  '_get_axis',
#  '_get_axis_name',
#  '_get_axis_number',
#  '_get_axis_resolvers',
#  '_get_block_manager_axis',
#  '_get_bool_data',
#  '_get_cleaned_column_resolvers',
#  '_get_column_array',
#  '_get_index_resolvers',
#  '_get_item_cache',
#  '_get_label_or_level_values',
#  '_get_numeric_data',
#  '_get_value',
#  '_getitem_bool_array',
#  '_getitem_multilevel',
#  '_gotitem',
#  '_hidden_attrs',
#  '_indexed_same',
#  '_info_axis',
#  '_info_axis_name',
#  '_info_axis_number',
#  '_info_repr',
#  '_init_mgr',
#  '_inplace_method',
#  '_internal_names',
#  '_internal_names_set',
#  '_is_copy',
#  '_is_homogeneous_type',
#  '_is_label_or_level_reference',
#  '_is_label_reference',
#  '_is_level_reference',
#  '_is_mixed_type',
#  '_is_view',
#  '_iset_item',
#  '_iset_item_mgr',
#  '_iset_not_inplace',
#  '_item_cache',
#  '_iter_column_arrays',
#  '_ixs',
#  '_join_compat',
#  '_logical_func',
#  '_logical_method',
#  '_maybe_cache_changed',
#  '_maybe_update_cacher',
#  '_metadata',
#  '_mgr',
#  '_min_count_stat_function',
#  '_needs_reindex_multi',
#  '_protect_consolidate',
#  '_reduce',
#  '_reduce_axis1',
#  '_reindex_axes',
#  '_reindex_columns',
#  '_reindex_index',
#  '_reindex_multi',
#  '_reindex_with_indexers',
#  '_rename',
#  '_replace_columnwise',
#  '_repr_data_resource_',
#  '_repr_fits_horizontal_',
#  '_repr_fits_vertical_',
#  '_repr_html_',
#  '_repr_latex_',
#  '_reset_cache',
#  '_reset_cacher',
#  '_sanitize_column',
#  '_series',
#  '_set_axis',
#  '_set_axis_name',
#  '_set_axis_nocheck',
#  '_set_is_copy',
#  '_set_item',
#  '_set_item_frame_value',
#  '_set_item_mgr',
#  '_set_value',
#  '_setitem_array',
#  '_setitem_frame',
#  '_setitem_slice',
#  '_slice',
#  '_stat_axis',
#  '_stat_axis_name',
#  '_stat_axis_number',
#  '_stat_function',
#  '_stat_function_ddof',
#  '_take_with_is_copy',
#  '_to_dict_of_blocks',
#  '_typ',
#  '_update_inplace',
#  '_validate_dtype',
#  '_values',
#  '_where',
#  'abs',
#  'add',
#  'add_prefix',
#  'add_suffix',
#  'agg',
#  'aggregate',
#  'align',
#  'all',
#  'any',
#  'append',
#  'apply',
#  'applymap',
#  'asfreq',
#  'asof',
#  'assign',
#  'astype',
#  'at',
#  'at_time',
#  'attrs',
#  'axes',
#  'backfill',
#  'belongs_to_collection',
#  'between_time',
#  'bfill',
#  'bool',
#  'boxplot',
#  'budget',
#  'cast',
#  'clip',
#  'columns',
#  'combine',
#  'combine_first',
#  'compare',
#  'convert_dtypes',
#  'copy',
#  'corr',
#  'corrwith',
#  'count',
#  'cov',
#  'crew',
#  'cummax',
#  'cummin',
#  'cumprod',
#  'cumsum',
#  'describe',
#  'diff',
#  'div',
#  'divide',
#  'dot',
#  'drop',
#  'drop_duplicates',
#  'droplevel',
#  'dropna',
#  'dtypes',
#  'duplicated',
#  'empty',
#  'eq',
#  'equals',
#  'eval',
#  'ewm',
#  'expanding',
#  'explode',
#  'ffill',
#  'fillna',
#  'filter',
#  'first',
#  'first_valid_index',
#  'flags',
#  'floordiv',
#  'from_dict',
#  'from_records',
#  'ge',
#  'genres',
#  'get',
#  'groupby',
#  'gt',
#  'half_runtime',
#  'head',
#  'hist',
#  'homepage',
#  'iat',
#  'id',
#  'idxmax',
#  'idxmin',
#  'iloc',
#  'imdb_id',
#  'index',
#  'infer_objects',
#  'info',
#  'insert',
#  'interpolate',
#  'isin',
#  'isna',
#  'isnull',
#  'items',
#  'iteritems',
#  'iterrows',
#  'itertuples',
#  'join',
#  'keys',
#  'kurt',
#  'kurtosis',
#  'last',
#  'last_valid_index',
#  'le',
#  'loc',
#  'lookup',
#  'lt',
#  'mad',
#  'mask',
#  'max',
#  'mean',
#  'median',
#  'melt',
#  'memory_usage',
#  'merge',
#  'min',
#  'mod',
#  'mode',
#  'movie_profit',
#  'mul',
#  'multiply',
#  'ndim',
#  'ne',
#  'new_profit',
#  'nlargest',
#  'notna',
#  'notnull',
#  'nsmallest',
#  'nunique',
#  'original_language',
#  'original_title',
#  'overview',
#  'pad',
#  'pct_change',
#  'pipe',
#  'pivot',
#  'pivot_table',
#  'plot',
#  'pop',
#  'popularity',
#  'poster_path',
#  'pow',
#  'prod',
#  'product',
#  'production_companies',
#  'production_countries',
#  'quantile',
#  'query',
#  'radd',
#  'rank',
#  'rdiv',
#  'reindex',
#  'reindex_like',
#  'release_date',
#  'rename',
#  'rename_axis',
#  'reorder_levels',
#  'replace',
#  'resample',
#  'reset_index',
#  'revenue',
#  'rfloordiv',
#  'rmod',
#  'rmul',
#  'rolling',
#  'round',
#  'rpow',
#  'rsub',
#  'rtruediv',
#  'runtime',
#  'sample',
#  'select_dtypes',
#  'sem',
#  'set_axis',
#  'set_flags',
#  'set_index',
#  'shape',
#  'shift',
#  'size',
#  'skew',
#  'slice_shift',
#  'sort_index',
#  'sort_values',
#  'spoken_languages',
#  'squeeze',
#  'stack',
#  'status',
#  'std',
#  'style',
#  'sub',
#  'subtract',
#  'sum',
#  'swapaxes',
#  'swaplevel',
#  'tagline',
#  'tail',
#  'take',
#  'title',
#  'to_clipboard',
#  'to_csv',
#  'to_dict',
#  'to_excel',
#  'to_feather',
#  'to_gbq',
#  'to_hdf',
#  'to_html',
#  'to_json',
#  'to_latex',
#  'to_markdown',
#  'to_numpy',
#  'to_parquet',
#  'to_period',
#  'to_pickle',
#  'to_records',
#  'to_sql',
#  'to_stata',
#  'to_string',
#  'to_timestamp',
#  'to_xarray',
#  'to_xml',
#  'transform',
#  'transpose',
#  'truediv',
#  'truncate',
#  'tz_convert',
#  'tz_localize',
#  'unstack',
#  'update',
#  'value_counts',
#  'values',
#  'var',
#  'where',
#  'xs']

# %%
#Importing Datetime Modules

# %%
from datetime import datetime
from datetime import date

# %%
df['release_date'][0:5]
# Out:
# 0     2/20/15
# 1      8/6/04
# 2    10/10/14
# 3      3/9/12
# 4      2/5/09
# Name: release_date, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
#  14  runtime                2998 non-null   float64
#  15  spoken_languages       2980 non-null   object
#  16  status                 3000 non-null   object
#  17  tagline                2403 non-null   object
#  18  title                  3000 non-null   object
#  19  Keywords               2724 non-null   object
#  20  cast                   3000 non-null   int64
#  21  crew                   2984 non-null   object
#  22  revenue                2996 non-null   float64
#  23  half_runtime           2998 non-null   float64
#  24  movie_profit           3000 non-null   int64
#  25  capitalised title      3000 non-null   object
#  26  new_profit             2996 non-null   float64
# dtypes: float64(5), int64(4), object(18)
# memory usage: 632.9+ KB

# %%
df['new_release_date']=df['release_date'].apply(lambda x :  datetime.strptime(x,'%m/%d/%y') )

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
#  14  runtime                2998 non-null   float64
#  15  spoken_languages       2980 non-null   object
#  16  status                 3000 non-null   object
#  17  tagline                2403 non-null   object
#  18  title                  3000 non-null   object
#  19  Keywords               2724 non-null   object
#  20  cast                   3000 non-null   int64
#  21  crew                   2984 non-null   object
#  22  revenue                2996 non-null   float64
#  23  half_runtime           2998 non-null   float64
#  24  movie_profit           3000 non-null   int64
#  25  capitalised title      3000 non-null   object
#  26  new_profit             2996 non-null   float64
#  27  new_release_date       3000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), int64(4), object(18)
# memory usage: 656.4+ KB

# %%
df['new_release_date'][0]
# Out:
# Timestamp('2015-02-20 00:00:00')

# %%
df['new_release_date'][0].month
# Out:
# 2

# %%
df['new_release_date'][0].year
# Out:
# 2015

# %%
df['new_release_date'][0].day
# Out:
# 20

# %%
df['new_release_date'][5]
# Out:
# Timestamp('1987-08-06 00:00:00')

# %%
# Month Year Date

print(df['new_release_date'][0].month)
print(df['new_release_date'][0].year)
print(df['new_release_date'][0].day)
print(df['new_release_date'][0].hour)
print(df['new_release_date'][0].minute)
# Out:
# 2
# 2015
# 20
# 0
# 0

# %%
print(date.today())
# Out:
# 2023-01-25

# %%
print(datetime.now())
# Out:
# 2023-01-25 14:52:14.178574

# %%
print(date.today())
# Out:
# 2023-01-25

# %%
#Operations on Datetime

from datetime import timedelta

# %%
print(date.today())
# Out:
# 2023-01-25

# %%
print(date.today())
print(date.today()-timedelta(days=1))
# Out:
# 2023-01-25
# 2023-01-24

# %%
print(date.today())
print(datetime.now()+timedelta(hours=5.5))
# Out:
# 2023-01-25
# 2023-01-25 20:22:14.258611

# %%
print(date.today())
print(datetime.now()+timedelta(seconds = 60))
# Out:
# 2023-01-25
# 2023-01-25 14:53:14.274611

# %%
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# 0                        [{'id': 35, 'name': 'Comedy'}]
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                         [{'id': 18, 'name': 'Drama'}]
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# ...                                                 ...
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                homepage    imdb_id original_language  \
# 0                                   NaN  tt2637294                en
# 1                                   NaN  tt0368933                en
# 2     http://sonyclassics.com/whiplash/  tt2582802                en
# 3            http://kahaanithefilm.com/  tt1821480                hi
# 4                                   NaN  tt1380152                ko
# ...                                 ...        ...               ...
# 2995                                NaN  tt0109403                en
# 2996                                NaN  tt2364975                sv
# 2997                                NaN  tt0116908                en
# 2998     http://www.alongcamepolly.com/  tt0343135                en
# 2999   http://www.abductionthefilm.com/  tt1600195                en
#
#                                 original_title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                         마린보이
# ...                                        ...
# 2995                                   Chasers
# 2996                               Vi är bäst!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                overview  popularity  ...  \
# 0     When Lou, who has become the "father of the In...    6.575393  ...
# 1     Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2     Under the direction of a ruthless instructor, ...   64.299990  ...
# 3     Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4     Marine Boy is the story of a former national s...    1.148070  ...
# ...                                                 ...         ...  ...
# 2995  Military men Rock Reilly and Eddie Devane are ...    9.853270  ...
# 2996  Three girls in 1980s Stockholm decide to form ...    3.727996  ...
# 2997  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
# 2998  Reuben Feffer is a guy who's spent his entire ...   15.725542  ...
# 2999  A young man sets out to uncover the truth abou...   10.512109  ...
#
#                                          title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                   Marine Boy
# ...                                        ...
# 2995                                   Chasers
# 2996                          We Are the Best!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                Keywords  cast  \
# 0     [{'id': 4379, 'name': 'time travel'}, {'id': 9...     1
# 1     [{'id': 2505, 'name': 'coronation'}, {'id': 42...     2
# 2     [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...     3
# 3     [{'id': 10092, 'name': 'mystery'}, {'id': 1054...     4
# 4                                                   NaN     5
# ...                                                 ...   ...
# 2995  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...  2996
# 2996  [{'id': 1192, 'name': 'sweden'}, {'id': 4470, ...  2997
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...  2998
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...  2999
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...  3000
#
#                                                    crew      revenue  \
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...          NaN
# 1     [{'credit_id': '52fe43fe9251416c7502563d', 'de...          NaN
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...          NaN
# 3     [{'credit_id': '52fe48779251416c9108d6eb', 'de...          NaN
# 4     [{'credit_id': '52fe464b9251416c75073b43', 'de...    3923970.0
# ...                                                 ...          ...
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687.0
# 2996  [{'credit_id': '5716b72ac3a3686678012c84', 'de...     180590.0
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761.0
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386.0
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155.0
#
#      half_runtime movie_profit                         capitalised title  \
# 0            46.5     -1685349                    hot tub time machine 2
# 1            56.5     55149435  the princess diaries 2: royal engagement
# 2            52.5      9792000                                  whiplash
# 3            61.0     14800000                                   kahaani
# 4            59.0      3923970                                marine boy
# ...           ...          ...                                       ...
# 2995         51.0      1596687                                   chasers
# 2996         51.0       180590                          we are the best!
# 2997         60.0     24456761                   the long kiss goodnight
# 2998         45.0    129963386                          along came polly
# 2999         53.0     47087155                                 abduction
#
#        new_profit new_release_date
# 0             NaN       2015-02-20
# 1             NaN       2004-08-06
# 2             NaN       2014-10-10
# 3             NaN       2012-03-09
# 4       3923970.0       2009-02-05
# ...           ...              ...
# 2995    1596687.0       1994-04-22
# 2996     180590.0       2013-03-28
# 2997   24456761.0       1996-10-11
# 2998  129963386.0       2004-01-16
# 2999   47087155.0       2011-09-22
#
# [3000 rows x 28 columns]

# %% [markdown]
# # Unique and Missing Values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 28 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
#  14  runtime                2998 non-null   float64
#  15  spoken_languages       2980 non-null   object
#  16  status                 3000 non-null   object
#  17  tagline                2403 non-null   object
#  18  title                  3000 non-null   object
#  19  Keywords               2724 non-null   object
#  20  cast                   3000 non-null   int64
#  21  crew                   2984 non-null   object
#  22  revenue                2996 non-null   float64
#  23  half_runtime           2998 non-null   float64
#  24  movie_profit           3000 non-null   int64
#  25  capitalised title      3000 non-null   object
#  26  new_profit             2996 non-null   float64
#  27  new_release_date       3000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), int64(4), object(18)
# memory usage: 656.4+ KB

# %%
list(df['status'].unique())
# Out:
# ['Released', 'Rumored']

# %%
list(df['original_language'].unique())
# Out:
# ['en',
#  'hi',
#  'ko',
#  'sr',
#  'fr',
#  'it',
#  'nl',
#  'zh',
#  'es',
#  'cs',
#  'ta',
#  'cn',
#  'ru',
#  'tr',
#  'ja',
#  'fa',
#  'sv',
#  'de',
#  'te',
#  'pt',
#  'mr',
#  'da',
#  'fi',
#  'el',
#  'ur',
#  'he',
#  'no',
#  'ar',
#  'nb',
#  'ro',
#  'vi',
#  'pl',
#  'hu',
#  'ml',
#  'bn',
#  'id']

# %%
list(df['belongs_to_collection'].unique())
# Out:
# ["[{'id': 313576, 'name': 'Hot Tub Time Machine Collection', 'poster_path': '/iEhb00TGPucF0b4joM1ieyY026U.jpg', 'backdrop_path': '/noeTVcgpBiD48fDjFVic1Vz7ope.jpg'}]",
#  "[{'id': 107674, 'name': 'The Princess Diaries Collection', 'poster_path': '/wt5AMbxPTS4Kfjx7Fgm149qPfZl.jpg', 'backdrop_path': '/zSEtYD77pKRJlUPx34BJgUG9v1c.jpg'}]",
#  nan,
#  "[{'id': 256377, 'name': 'The Muppet Collection', 'poster_path': '/8Ew8EIdFFurMMYjSbWPu1Hl4vLX.jpg', 'backdrop_path': '/1AWd3MM90G47mxtD112gRDxSXY9.jpg'}]",
#  "[{'id': 1575, 'name': 'Rocky Collection', 'poster_path': '/mCY5dMkSSFQufGCViI6jNUU6pXq.jpg', 'backdrop_path': '/w4h6gjdWPvmu5R9H6zeGDPo1ZuV.jpg'}]",
#  "[{'id': 48190, 'name': 'Revenge of the Nerds Collection', 'poster_path': '/qOnoXEdrSnBuS3FMAFRIgyJSM2r.jpg', 'backdrop_path': None}]",
#  "[{'id': 91698, 'name': 'Chili Palmer Collection', 'poster_path': '/ae3smJDdWrMJ77tDpYOrpo4frKq.jpg', 'backdrop_path': '/uWaANGQeoSs5vSP1CWtlkDrkqei.jpg'}]",
#  "[{'id': 9518, 'name': 'The Transporter Collection', 'poster_path': '/uakYnYtFxqjS8pjEWW9lGWmdMRz.jpg', 'backdrop_path': '/qDuTIGAEbxF3jP9zNILLAoxNLpU.jpg'}]",
#  "[{'id': 9735, 'name': 'Friday the 13th Collection', 'poster_path': '/uobgqpLQff9WvxGKE2OSvXv1RHm.jpg', 'backdrop_path': '/c7pMKwv5NzIN6N3KM4L8fYMTtPw.jpg'}]",
#  "[{'id': 207621, 'name': 'V/H/S Collection', 'poster_path': '/esfk62fcqTWqB90dAHaVMbDWmbM.jpg', 'backdrop_path': '/wSdVm0uxEvYlwMxOAhipUUzey4w.jpg'}]",
#  "[{'id': 207632, 'name': 'The ABCs of Death Collection', 'poster_path': '/fzrKAtcg75Je7N0NereOdKePHDM.jpg', 'backdrop_path': None}]",
#  "[{'id': 90863, 'name': 'Rush Hour Collection', 'poster_path': '/pTjvzlYByJuZ4TTkmlHIe4aDFy2.jpg', 'backdrop_path': '/uoDt3eCCKpcxSQVWjPTgN8T0gjm.jpg'}]",
#  "[{'id': 376970, 'name': 'Cocaine Cowboys', 'poster_path': '/ysCY4Q91US7zEr78raJBc27KPxF.jpg', 'backdrop_path': '/3vT6FzqHeT7onqUAMjKk7FqARRD.jpg'}]",
#  "[{'id': 8354, 'name': 'Ice Age Collection', 'poster_path': '/stQoHvo0q6ZcEkji2Z1wlAxKnDq.jpg', 'backdrop_path': '/2Mb92Ssoe1eUecvrCe2pEvgAlmv.jpg'}]",
#  "[{'id': 115570, 'name': 'Star Trek: The Next Generation Collection', 'poster_path': '/sddV6vaUC6x37icJS3opIXTXB07.jpg', 'backdrop_path': '/r7MMQenUURHhAVHFymtOb8AX4Bm.jpg'}]",
#  "[{'id': 120794, 'name': 'Batman Collection', 'poster_path': '/adQxUvQW8HXNsvMG5aj71pHh9T.jpg', 'backdrop_path': '/9SpZvXLZDGGtFqVDByGqSGI64Kw.jpg'}]",
#  "[{'id': 645, 'name': 'James Bond Collection', 'poster_path': '/HORpg5CSkmeQlAolx3bKMrKgfi.jpg', 'backdrop_path': '/6VcVl48kNKvdXOZfJPdarlUGOsk.jpg'}]",
#  "[{'id': 36694, 'name': 'Bloodsport Collection', 'poster_path': '/sTqv7FQalXNVGSpfSJaWek077w9.jpg', 'backdrop_path': '/1DXtjAAaK7597GV5MSZH6nn0uqS.jpg'}]",
#  "[{'id': 9485, 'name': 'The Fast and the Furious Collection', 'poster_path': '/mCkqJf4ijbNoBWvJ0RTWZJuhJUA.jpg', 'backdrop_path': '/z5A5W3WYJc3UVEWljSGwdjDgQ0j.jpg'}]",
#  "[{'id': 230161, 'name': 'Fright Night (Reboot) Collection', 'poster_path': '/j552uoYU3B45mIHLPBorkdoW0Mr.jpg', 'backdrop_path': '/9N1PbMkYJ5Zn2suUSHt38lAJnkD.jpg'}]",
#  "[{'id': 104847, 'name': 'Caddyshack Collection', 'poster_path': '/yMNHFk8vcWSnzDduz7OZyPhCUrQ.jpg', 'backdrop_path': '/nt3U4uU8GJz2zg2oTXSUFbFhI6j.jpg'}]",
#  "[{'id': 4438, 'name': 'The Space Odyssey Series', 'poster_path': '/i1WdRtc6aObiwGz5NU8WWPW3r1N.jpg', 'backdrop_path': '/15FumSExI9SRoL7QJWZAsA0b10c.jpg'}]",
#  "[{'id': 2883, 'name': 'Kill Bill Collection', 'poster_path': '/tf1nUtw3LJGUGv1EFFi23iz6ngr.jpg', 'backdrop_path': '/oCLKNACMNrEf4T1EP6BpMXDl5m1.jpg'}]",
#  "[{'id': 131989, 'name': 'Recep İvedik Serisi', 'poster_path': '/c53DOjhOlBlk0k197EoFkFTP7N4.jpg', 'backdrop_path': '/iky3AtcC5FpdIhF9SCYavEUKUQE.jpg'}]",
#  "[{'id': 119, 'name': 'The Lord of the Rings Collection', 'poster_path': '/p4UokEk2XnjjRTdXGe6DLYXlbI1.jpg', 'backdrop_path': '/bccR2CGTWVVSZAG0yqmy3DIvhTX.jpg'}]",
#  "[{'id': 106768, 'name': 'Tarzan (Animation) Collection', 'poster_path': '/A7ox3LFDn87561sddxe2nZfpahX.jpg', 'backdrop_path': '/esBiZuIJyxr6sZL0OqkILcOkoUX.jpg'}]",
#  '[{\'id\': 255478, \'name\': "Cowgirls n\' Angels Collection", \'poster_path\': \'/p8hwMZbeNe6qQFlblm1DjKrvYOu.jpg\', \'backdrop_path\': None}]',
#  "[{'id': 748, 'name': 'X-Men Collection', 'poster_path': '/1Zo4J5SAni8lyXt7NxJwJZ0f0ip.jpg', 'backdrop_path': '/Abnosho2v3bcdvDww6T7Hfeczm1.jpg'}]",
#  "[{'id': 9338, 'name': 'Police Academy Collection', 'poster_path': '/1VRdXVy2FYlX4EtllnLKWK6kYDJ.jpg', 'backdrop_path': '/RhpI828r9EKPV4x0pyHiqCDZDQ.jpg'}]",
#  "[{'id': 168880, 'name': 'Beethoven Collection', 'poster_path': '/pdaH4A7ecsThnSX5sOpwrcntziF.jpg', 'backdrop_path': '/ogXWk8vtx6Pn6kEiak8VQmFCqit.jpg'}]",
#  "[{'id': 55422, 'name': 'Peter Pan Collection', 'poster_path': '/t0mINaIut2aDKdGseQtC7UcbRNW.jpg', 'backdrop_path': '/AnhKboZjfeGuHI6qg7pp9RCesTF.jpg'}]",
#  "[{'id': 106011, 'name': 'Shadow Boxing Collection', 'poster_path': '/dGd4SGR3MuHUgG4WWyl8YO1uVpZ.jpg', 'backdrop_path': '/v5LLxWvV9bZWkBf1uUb7cruSQm8.jpg'}]",
#  "[{'id': 173344, 'name': 'Qatsi Collection', 'poster_path': '/AlE6QJc87zH5vYw6AI779ywRZG6.jpg', 'backdrop_path': '/2pRLc3z0jE1WkFJLCZyITtYjo08.jpg'}]",
#  "[{'id': 937, 'name': 'The Pink Panther (Original) Collection', 'poster_path': '/xu6gZ0zGUSR8SC2QLKFaUrX2niM.jpg', 'backdrop_path': '/6KE7AguGR3UqwUn5RkzkoBc3MLy.jpg'}]",
#  "[{'id': 8945, 'name': 'Mad Max Collection', 'poster_path': '/jZowUf4okNYuSlgj5iURE7CDMho.jpg', 'backdrop_path': '/zI0q2ENcQOLECbe0gAEGlncVh2j.jpg'}]",
#  "[{'id': 434270, 'name': 'Lew Harper Collection', 'poster_path': None, 'backdrop_path': None}]",
#  "[{'id': 59586, 'name': 'The Blue Lagoon collection', 'poster_path': '/A4U11Zhp5KjiKOrghNlqNlmrbhw.jpg', 'backdrop_path': '/m8LAOuIhlCBr6dWdtVF2C2ioMrc.jpg'}]",
#  "[{'id': 466004, 'name': 'A Few Best Men Collection', 'poster_path': None, 'backdrop_path': None}]",
#  "[{'id': 5039, 'name': 'Rambo Collection', 'poster_path': '/feGOEOVrOLyjtEnVa88rQLgD3XY.jpg', 'backdrop_path': '/Yt2ZxbJv2HM842B6FNMr59Vhyb.jpg'}]",
#  "[{'id': 101385, 'name': 'Trailer Park Boys Collection', 'poster_path': '/rnpQXPaiiS90KidhNI34maU9aiW.jpg', 'backdrop_path': '/wy72negkJZcoOKkYkaWR7qgSXSF.jpg'}]",
#  "[{'id': 8917, 'name': 'Hellraiser Collection', 'poster_path': '/lIK0UgJsA18Z5I1PwpucXzgyF3A.jpg', 'backdrop_path': '/uaEUgCqB6lGkvM4Wy5blNwLJdfa.jpg'}]",
#  "[{'id': 373538, 'name': 'Enter the Ninja Collection', 'poster_path': '/zmHiLeY4Mr0l5ZB9LIr42XNb5rN.jpg', 'backdrop_path': '/cj7F0fz5NGWhZKZmqxRnN7SpQc5.jpg'}]",
#  "[{'id': 286162, 'name': 'Power Rangers Collection', 'poster_path': '/zyHCzQUkgaemgCMEplqAqsp83SA.jpg', 'backdrop_path': '/ddGPthtIvNM2f8qBAyxa5GSKskK.jpg'}]",
#  "[{'id': 2366, 'name': 'The Jaws Collection', 'poster_path': '/fgraZdDCvAtBr0MHczmL6raonHd.jpg', 'backdrop_path': '/us13Po7SYoHl9wBNVcz04t0oh7F.jpg'}]",
#  "[{'id': 148065, 'name': 'Doraemon Collection', 'poster_path': '/69oxxREwOQBa5QISbH2gvBCyds2.jpg', 'backdrop_path': '/rc6OFcSasL5YxBRPUQVwxmVF6h5.jpg'}]",
#  "[{'id': 112537, 'name': 'Sällskapsresorna', 'poster_path': '/t80sQEt4AHUmNmpSVYanCnKSGHG.jpg', 'backdrop_path': '/oO7O5kcxrr0ZUC3qcO3y8Q0OM0m.jpg'}]",
#  "[{'id': 86336, 'name': 'Basic Instinct Collection', 'poster_path': '/hiM5EvFgjFboZtPMY5vFjhNnRQc.jpg', 'backdrop_path': '/o5rgryRLwlOApsO3toqpqhhdS7H.jpg'}]",
#  "[{'id': 115142, 'name': 'Tales from the Crypt Collection', 'poster_path': '/mjP1Ktqz3VCyX2akRAIjgxaALwx.jpg', 'backdrop_path': '/o9Nll2BovcZ9EDmBBMmnHx99wP4.jpg'}]",
#  "[{'id': 469613, 'name': 'Los Leguineche - Colección', 'poster_path': None, 'backdrop_path': None}]",
#  "[{'id': 43072, 'name': 'The Mask Collection', 'poster_path': '/pl2vNt9XlxITTgm8wCQ2Y6ThkpT.jpg', 'backdrop_path': '/ucDNm5TJW1ji7kIjnX2SZYm7ATM.jpg'}]",
#  "[{'id': 115840, 'name': 'Would I Lie to You? Collection', 'poster_path': '/zHNB1c9ABRWhMknTuUXvz2XtV9B.jpg', 'backdrop_path': '/wJueJlh2mzbZYkjgR7jNBDfIXG6.jpg'}]",
#  "[{'id': 23026, 'name': 'Ghost in the Shell Collection', 'poster_path': '/xEQVBrAd1hWtwCeK39RQ84CRqB7.jpg', 'backdrop_path': '/xt0E8CHXzLxEoiPqrjZMRrM4Izi.jpg'}]",
#  "[{'id': 182813, 'name': 'Clerks Collection', 'poster_path': '/qEjGvJ9I2ak6ENjdJ23dfjqLkAK.jpg', 'backdrop_path': '/6Fjkbh2DVAvVZa3c1HamblAN5Bg.jpg'}]",
#  "[{'id': 86110, 'name': 'Diary of a Wimpy Kid Collection', 'poster_path': '/4Miizfzuds4ldROTff9vB0Z3EId.jpg', 'backdrop_path': '/hTbw2nLM44eE5m7ZIIXodcoDR1X.jpg'}]",
#  "[{'id': 381396, 'name': 'Bats Collection', 'poster_path': None, 'backdrop_path': None}]",
#  "[{'id': 131635, 'name': 'The Hunger Games Collection', 'poster_path': '/ttbKy12hDjSHQcM7sCoeW1WsDlW.jpg', 'backdrop_path': '/zWiiLNg8yXv0he3tCH6XignPaYV.jpg'}]",
#  "[{'id': 350836, 'name': 'Dark Planet Collection', 'poster_path': None, 'backdrop_path': None}]",
#  "[{'id': 91799, 'name': 'Tremors Collection', 'poster_path': '/dCeNEdBgkpXMIAndv02JI3DXzKj.jpg', 'backdrop_path': '/87K8X2WixRlR3LxzeydW83N7nM0.jpg'}]",
#  "[{'id': 46512, 'name': 'Missing in Action Collection', 'poster_path': '/t1pfgb8r4Kx3qLN4H8vDZdfD50R.jpg', 'backdrop_path': '/6VIGk6OIqlKWrb4rjTvDklBfv1n.jpg'}]",
#  "[{'id': 87118, 'name': 'Cars Collection', 'poster_path': '/uq3N2SFj1Y06zA6LzCQPkmBdaaE.jpg', 'backdrop_path': '/yPyhZ5OpYs68Bb8u0PZ1tH0QIgd.jpg'}]",
#  "[{'id': 102019, 'name': 'Death Note Collection', 'poster_path': '/jh35G1kYbqEOddhxny6KmRHc9FI.jpg', 'backdrop_path': '/2y42CZ6LTtpJKYRf0dUEFQ13W9f.jpg'}]",
#  "[{'id': 3169, 'name': 'Dr. Dolittle Collection', 'poster_path': '/gCY8N724wNeAfegWCAkTjUSMr34.jpg', 'backdrop_path': '/dtz0ju3dikZaiSJ9HmVoMs9imT8.jpg'}]",
#  "[{'id': 92012, 'name': 'Happy Feet Collection', 'poster_path': '/pYbF2FAi2MEVshl8jCDNTRNdTF0.jpg', 'backdrop_path': '/b9CLLxKsh63AHEkGE9nz9bupQqh.jpg'}]",
#  "[{'id': 382685, 'name': 'Now You See Me Collection', 'poster_path': '/n0ygWnRip5RYnejdI6Lpwxov0x7.jpg', 'backdrop_path': '/scBzORmLqP00h8hPKS19TLtyRQm.jpg'}]",
#  "[{'id': 110177, 'name': 'Goal! Collection', 'poster_path': '/jaUSrep1RTzr73QPN3DNkW4LiRn.jpg', 'backdrop_path': '/mKTYkGMseCEFXuZ4CjuZ00xXRCd.jpg'}]",
#  "[{'id': 142680, 'name': 'Alex Cross Collection', 'poster_path': '/64mlnEVoq1I0BZe4iDdAv89qO9Z.jpg', 'backdrop_path': '/eyKpawn8yMq6kdv03wgKruMuSJX.jpg'}]",
#  "[{'id': 192492, 'name': 'The Jack Ryan Collection', 'poster_path': '/uCuiExsQDyJagov5aVAyw38YEm.jpg', 'backdrop_path': '/qYlcVBifq5T4wyWV00a5Awq0kUi.jpg'}]",
#  "[{'id': 170754, 'name': 'Arthur Collection', 'poster_path': '/bdRCMpvyTX1zPR28GHcFjjA3LHt.jpg', 'backdrop_path': '/c0XFWONQ39hfOCJIg3FUuRoGgH0.jpg'}]",
#  "[{'id': 94032, 'name': 'The Lion King Collection', 'poster_path': '/oG1heUs503GV6xBnFhgyYTGWm05.jpg', 'backdrop_path': '/A9IEaj9cPAwEgFnTmteB70oxgJY.jpg'}]",
#  "[{'id': 343944, 'name': 'Singam Collection', 'poster_path': None, 'backdrop_path': None}]",
#  "[{'id': 2396, 'name': 'Asterix and Obelix Collection', 'poster_path': '/f6C6tDEU3aJndJokSLvYLuwVt0k.jpg', 'backdrop_path': '/vm0i4KIscrTiUsri21z1SOIG4fo.jpg'}]",
#  "[{'id': 98513, 'name': 'Behind Enemy Lines Collection', 'poster_path': '/baDDWPQgZyBKiDNeipLJ9LEZ5BX.jpg', 'backdrop_path': '/5sMWk8wutGCFAM7MAFPQJyc0ny0.jpg'}]",
#  "[{'id': 57129, 'name': 'Rugrats Collection', 'poster_path': '/zamw6yLqCFqAHG1HPSPOCws82Bb.jpg', 'backdrop_path': '/pFgV70FI1URDLFY3bllhPl6sC33.jpg'}]",
#  "[{'id': 103372, 'name': 'Mr. Bean Collection', 'poster_path': '/61Jcc1Gwc2KE7sIJ1HPqqdt67ji.jpg', 'backdrop_path': '/aIXcqHz5VKRLXHPsNo0dFoK7YP5.jpg'}]",
#  "[{'id': 307637, 'name': 'Jingle All the Way Collection', 'poster_path': '/8lId3K1HKp39peVG1VwLfA6RFsK.jpg', 'backdrop_path': '/grCEwz2sIneF1wlDtVx6UiLqtLc.jpg'}]",
#  "[{'id': 101688, 'name': 'Cannonball Run Collection', 'poster_path': '/8Bq9YD1UIw1hdkccegKVaUipBH9.jpg', 'backdrop_path': '/ogcQ0P7d1qY8S0CUWOeUrSa1BSB.jpg'}]",
#  "[{'id': 3601, 'name': 'I Know What You Did Last Summer Collection', 'poster_path': '/2g6Ui3CCNcDtL4wasCziivogpfW.jpg', 'backdrop_path': '/g7RBq92ijQg1MAF2hF69rWT6Ux8.jpg'}]",
#  '[{\'id\': 91746, \'name\': "Bill & Ted\'s Most Excellent Collection", \'poster_path\': \'/e8ytcWY0r32q3RdNJDnv5KRh9hC.jpg\', \'backdrop_path\': \'/m7KWyG7VwXoPbwr3DgeDqed8qU0.jpg\'}]',
#  "[{'id': 8091, 'name': 'Alien Collection', 'poster_path': '/iVzIeC3PbG9BtDAudpwSNdKAgh6.jpg', 'backdrop_path': '/kB0Y3uGe9ohJa59Lk8UO9cUOxGM.jpg'}]",
#  "[{'id': 10453, 'name': 'Poltergeist Collection', 'poster_path': '/8Z6P04pKGvCnkmHdAl2lmbfAIbN.jpg', 'backdrop_path': '/i8QZZV1olny9FCPNrxAL7Kk9CJy.jpg'}]",
#  "[{'id': 228887, 'name': 'Daddy Day Camp Collection', 'poster_path': '/x6sXJspIoqj3CWqSfv8IYxukKP9.jpg', 'backdrop_path': '/hQXX7E22e1xJVudoNgZJn95BIAl.jpg'}]",
#  "[{'id': 52749, 'name': 'The Butterfly Effect Collection', 'poster_path': '/8lkeUgXNSB0foS3wU7rkuMTdMKV.jpg', 'backdrop_path': '/7DsbbkQAKSci07Jp4fJVq3QXSEF.jpg'}]",
#  "[{'id': 86117, 'name': 'Johnny English Collection', 'poster_path': '/3a2BVS2aFHK66pnIqFKcJ9HaC45.jpg', 'backdrop_path': '/pMHHhMKu2iQichL6Eym4ApCvIEB.jpg'}]",
#  "[{'id': 125570, 'name': '300 Collection', 'poster_path': '/nKQqh6kJvPdpOJD24enD3Bm1Hy5.jpg', 'backdrop_path': '/mLLztGKyxSLoWjgRSpmm9W12VsU.jpg'}]",
#  "[{'id': 10713, 'name': 'Universal Soldier Collection', 'poster_path': '/vz9ym8LnmyvEAm4ms9PH8JUmUuQ.jpg', 'backdrop_path': '/bonZuSo9YE7LFHEFE8oLD3qv32o.jpg'}]",
#  "[{'id': 9435, 'name': 'Babe Collection', 'poster_path': '/jgnah0k4AumfcZE4HHMJywYHvG6.jpg', 'backdrop_path': '/zRWuGdIlkWqXMQcs1t3sPy1XQ6x.jpg'}]",
#  "[{'id': 389767, 'name': 'My Big Fat Greek Wedding Collection', 'poster_path': '/oalS0sTGzk2mgiAyOQ5iVR4juJC.jpg', 'backdrop_path': '/UzzUEBULGUuk695tZhLO9xShxV.jpg'}]",
#  "[{'id': 9649, 'name': 'Mexico Trilogy', 'poster_path': '/qmPhILSFQKaRyc81mVJWl05tHai.jpg', 'backdrop_path': '/6p1OzuIKWnTDfDea7IpB9xra5J.jpg'}]",
#  "[{'id': 8580, 'name': 'The Karate Kid Collection', 'poster_path': '/o6h2F0C5eZOy50Q76fNYzc9mvvw.jpg', 'backdrop_path': '/1ok5JGCsDt4Sh3CkFeXh2F2KB7F.jpg'}]",
#  "[{'id': 86119, 'name': 'The Hangover Collection', 'poster_path': '/aMmNLuyXvdBih1R5RRHtdtNaS6N.jpg', 'backdrop_path': '/uEtsf26a9RsRDy85MOIv1xAj44x.jpg'}]",
#  "[{'id': 265865, 'name': 'Space Dogs', 'poster_path': None, 'backdrop_path': None}]",
#  "[{'id': 166373, 'name': 'The Marine Collection', 'poster_path': '/7sPY1VK4yD5Zlv16DUei65rtrjn.jpg', 'backdrop_path': '/rpUficLJq3I7GvRafTVT1TVRsms.jpg'}]",
#  "[{'id': 122123, 'name': 'Three Heroes Collection', 'poster_path': '/aH6Y1srPOtl2djeJEoOyYNF2vNW.jpg', 'backdrop_path': '/7w8qHVqkc2y9GyBrSCUXHASXjt6.jpg'}]",
#  "[{'id': 256322, 'name': 'The Purge Collection', 'poster_path': '/nP3c8mTSxlis4vfg0UjlkK8LRG9.jpg', 'backdrop_path': '/quFWGOA4I5KCTsyDbvLh6PHNZwv.jpg'}]",
#  "[{'id': 185103, 'name': 'Hotel Transylvania Collection', 'poster_path': '/zRNpkbP9QpcV2wz9dFzCzdG9fSD.jpg', 'backdrop_path': '/arH2YrpG7EVMnA4JCtzAXt9wQQJ.jpg'}]",
#  "[{'id': 134011, 'name': 'The Fugitive / U.S. Marshals Collection', 'poster_path': '/idhUzfuEC24PTYhkWasivjoA3O0.jpg', 'backdrop_path': '/9xbrJQoHkTgkXY8oDsTmND0FiEX.jpg'}]",
#  "[{'id': 170452, 'name': 'Timecop Collection', 'poster_path': '/7MzxlFFswI2OB7PifjnyMrrYke5.jpg', 'backdrop_path': '/mIqsp7AFmyTYjJ4N9qv3FhAUz60.jpg'}]",
#  "[{'id': 206559, 'name': 'StreetDance Collection', 'poster_path': '/d0xdu3kaMbQ8FnJkfWI2tfpMATC.jpg', 'backdrop_path': '/mkqD8O0CJxaZf6V0ps2DyZee4HP.jpg'}]",
#  "[{'id': 143757, 'name': 'Stir of Echoes Collection', 'poster_path': None, 'backdrop_path': None}]",
#  "[{'id': 468552, 'name': 'Wonder Woman Collection', 'poster_path': '/yEczguvMSFJRuUiOFgWXsZG3CsG.jpg', 'backdrop_path': '/n9KlvCOBFDmSyw3BgNrkUkxMFva.jpg'}]",
#  "[{'id': 366444, 'name': 'Demetrius Filmreihe', 'poster_path': None, 'backdrop_path': None}]",
#  "[{'id': 399, 'name': 'Predator Collection', 'poster_path': '/6Z7lASptoiRVxiCFvZaFgH9qp7u.jpg', 'backdrop_path': '/fXVzk9OxQwROCuiWvd0Cv76qmZi.jpg'}]",
#  "[{'id': 84, 'name': 'Indiana Jones Collection', 'poster_path': '/lpxDrACKJhbbGOlwVMNz5YCj6SI.jpg', 'backdrop_path': '/6kh59mZizZsttZPR0HAdXk6Ve2n.jpg'}]",
#  "[{'id': 426103, 'name': 'Ouija Collection', 'poster_path': '/Hn8bic15hWcTVJnZkf6WGu5Mm7.jpg', 'backdrop_path': '/m5nPr3cOxqzU68luWfwNngazHnE.jpg'}]",
#  "[{'id': 95051, 'name': 'The Up Series', 'poster_path': '/nLIBjyGeV2TMiv82MmKq5zX9DhG.jpg', 'backdrop_path': None}]",
#  "[{'id': 405393, 'name': 'The Black Stallion Collection', 'poster_path': '/1B4F7R10v5JL9Qplqttl5h9LVEe.jpg', 'backdrop_path': '/iyWB8vLTJQemdLahc82NRR7jb86.jpg'}]",
#  "[{'id': 320064, 'name': 'El pico - Colección', 'poster_path': '/kcjg2UlqqUqv232gjcLtSWZHS2x.jpg', 'backdrop_path': None}]",
#  "[{'id': 1565, 'name': '28 Days/Weeks Later Collection', 'poster_path': '/4AeGz1Jwnq6ky2kfLT95Tm8nEiw.jpg', 'backdrop_path': '/bpn1vynevsKLwAMRikY1L6cb18p.jpg'}]",
#  "[{'id': 105625, 'name': 'House of 1000 Corpses Collection', 'poster_path': '/7xpo52YDhHNFG5qdrLxhG58k0ke.jpg', 'backdrop_path': '/osLewbX6FJMy1iUcNHm6hoiNH0j.jpg'}]",
#  "[{'id': 8936, 'name': 'Bridget Jones Collection', 'poster_path': '/fB3BE3TL85Wh7dxNJf226IYQCp.jpg', 'backdrop_path': '/jiS4x140miaEH524CAFTvuxrcZ1.jpg'}]",
#  "[{'id': 45154, 'name': 'Darkman Collection', 'poster_path': '/mHrcic92RHbKHDi5Lxdhu5job6X.jpg', 'backdrop_path': '/oVqe4GNZkbWPppmvIyxFmyZNPhx.jpg'}]",
#  "[{'id': 10924, 'name': 'From Dusk Till Dawn Collection', 'poster_path': '/a156nAy5ZTGXlO5wgfvnF26aaDB.jpg', 'backdrop_path': '/oIJQPVy33uxBAu9LMXwjsgHLyxP.jpg'}]",
#  "[{'id': 17255, 'name': 'Resident Evil Collection', 'poster_path': '/bqnMPsZr9vhjJIwLxc3XzHkYORM.jpg', 'backdrop_path': '/8utTJ9WoQeYcZ0Ztciv6auqwLXl.jpg'}]",
#  "[{'id': 123800, 'name': 'Before... Collection', 'poster_path': '/giaxAC74fht0LVQ4WKVoDzLM2Iy.jpg', 'backdrop_path': '/wtNugZq8ZzBYwPIh3VoNUJdkBWG.jpg'}]",
#  "[{'id': 107725, 'name': 'Creepshow Collection', 'poster_path': '/wvoSFYgc36Zz2j8eDvysKDW1FZ.jpg', 'backdrop_path': '/yGxQgs3qBfmKk7VKT8VfyLKkA1I.jpg'}]",
#  "[{'id': 144200, 'name': 'Swan Princess Series', 'poster_path': '/3qBPAUFUMOOT9KqUEYXWAKy93Ge.jpg', 'backdrop_path': '/wxKt5KHvMYUSLHvyPf2xj64y3dJ.jpg'}]",
#  "[{'id': 366826, 'name': 'Navarone Collection', 'poster_path': '/vCZqWt03pj8Tydt04H12XiJ0NZk.jpg', 'backdrop_path': '/quXPBggya3DoHnxZZ6urOR9e6vR.jpg'}]",
#  "[{'id': 195441, 'name': 'Dennis the Menace Collection', 'poster_path': '/gSJO149uXqwqkTNfCYyj5KnMLW6.jpg', 'backdrop_path': None}]",
#  "[{'id': 9744, 'name': 'Fantastic Four Collection', 'poster_path': '/prObnUSCHIBC8ZjkGo2KHgjkWOo.jpg', 'backdrop_path': '/3JFe9AWoKuQWox7HO8HKgYRMOF7.jpg'}]",
#  "[{'id': 221966, 'name': 'The Odd Couple Collection', 'poster_path': '/iSRzUpJBro5vgskqVlCNOvXNxjh.jpg', 'backdrop_path': '/kY2nJgcvBgjLuAJxygbXYv1el2h.jpg'}]",
#  "[{'id': 91430, 'name': 'The Neverending Story Collection', 'poster_path': '/tXuOhgEbXoba7vVIybzGlnycoNq.jpg', 'backdrop_path': '/2IqXJIR1i0f6Ngq3A6rjXhQNqFc.jpg'}]",
#  "[{'id': 86092, 'name': 'Step Up Collection', 'poster_path': '/f4KxUp5IL5sgoDzFUL9GoUfy01C.jpg', 'backdrop_path': '/3jr0rQcsWyfqBlmzE0h0igjJohS.jpg'}]",
#  "[{'id': 529, 'name': 'Wallace & Gromit Collection', 'poster_path': '/993pCCMO9g9RQUtNDxQgE1B330H.jpg', 'backdrop_path': '/huyrvVKEKa9czUY89fnvaAVAtkX.jpg'}]",
#  "[{'id': 312977, 'name': 'Iron Sky Collection', 'poster_path': '/naglSR1dCuhpX0MHjSa4Cb9YObm.jpg', 'backdrop_path': None}]",
#  "[{'id': 86668, 'name': 'Elektra Luxx Collection', 'poster_path': '/6HP0JujRP7IUhymQW1IZPtqbxsi.jpg', 'backdrop_path': '/o2fZZfJH3c3EB8DXWz7jenonlCm.jpg'}]",
#  "[{'id': 121938, 'name': 'The Hobbit Collection', 'poster_path': '/hm2VtxeCBqWJnPNmvXPPXiHydyp.jpg', 'backdrop_path': '/7wO7MSnP5UcwR2cTHdJFF1vP4Ie.jpg'}]",
#  "[{'id': 96871, 'name': 'Father of the Bride Collection', 'poster_path': '/nts4iOmNnq7GNicycMJ9pSAn204.jpg', 'backdrop_path': '/7qwE57OVZmMJChBpLEbJEmzUydk.jpg'}]",
#  "[{'id': 179892, 'name': 'Kick-Ass Collection', 'poster_path': '/2UzHizIS6Z87ocDdY4TALPj1EqD.jpg', 'backdrop_path': '/fYMsCXEMguNlSORJIHydfBgOnty.jpg'}]",
#  "[{'id': 328372, 'name': 'Mall Cop Collection', 'poster_path': '/dpI0Ms55QByARcgeMf0YK1z2x3D.jpg', 'backdrop_path': '/29gIFb0wzsl2ArW9HZ2S2ERdDp4.jpg'}]",
#  "[{'id': 10, 'name': 'Star Wars Collection', 'poster_path': '/ghd5zOQnDaDW1mxO7R5fXXpZMu.jpg', 'backdrop_path': '/d8duYyyC9J5T825Hg7grmaabfxQ.jpg'}]",
#  "[{'id': 376650, 'name': 'Ride Along Collection', 'poster_path': '/7bjrke8mdxWG3PnFgvipbEOhc0Q.jpg', 'backdrop_path': '/3ZX5hvXjMxWJ5joyJxmWJT5nZDo.jpg'}]",
#  "[{'id': 2806, 'name': 'American Pie Collection', 'poster_path': '/twY1eM88fu8CCGVtem5ItlrgeDA.jpg', 'backdrop_path': '/3ptXtaqzAZlMXn3nZxaYke4anmK.jpg'}]",
#  "[{'id': 126125, 'name': 'The Expendables Collection', 'poster_path': '/ptF9rVkzoXVO1bnglLISgnJ7Ccr.jpg', 'backdrop_path': '/lA7oDSt6LkyDqtbFGbyuG0afmTI.jpg'}]",
#  "[{'id': 19160, 'name': 'FernGully Collection', 'poster_path': '/vXxfiihxZDd4M3EYYvEaXcHsab2.jpg', 'backdrop_path': '/eWikaqHnqLYtCh7pkBeZY3Y5QSm.jpg'}]",
#  "[{'id': 74508, 'name': '[REC] Collection', 'poster_path': '/jTA37dMZVUFej20EoM5SomKtnYi.jpg', 'backdrop_path': '/rDzuccVBZSyNVQ26hTRT0DvneVA.jpg'}]",
#  "[{'id': 99635, 'name': 'A Better Tomorrow Collection', 'poster_path': '/b7UQJjwIXLtKejp5FvspTqRh9VP.jpg', 'backdrop_path': '/mLtlXvBFG6Q2BZHkeciWO3BYfhH.jpg'}]",
#  "[{'id': 33514, 'name': 'The Twilight Collection', 'poster_path': '/2o4zgGjVryMOPdNqLZWsSPqRkOH.jpg', 'backdrop_path': '/rv5b06YAvmekw0D6Ul2ps9JbH4C.jpg'}]",
#  "[{'id': 229932, 'name': 'Rio Collection', 'poster_path': '/AuaToCmX55xDycK4oFJEYMgcK0O.jpg', 'backdrop_path': '/ndCkoXtdQErEb7RAfq0Y93xZzoG.jpg'}]",
#  "[{'id': 4563, 'name': 'The Vengeance Collection', 'poster_path': '/ilyS5xmHzMtTq4ngVRNKvZEbSRo.jpg', 'backdrop_path': '/t5zZZOvXK8m5z1omMdEEWcL6ywl.jpg'}]",
#  "[{'id': 72119, 'name': 'Honey, I Shrunk the Kids Collection', 'poster_path': '/xxIwqQARS0RZu5cIENahqZSRw2a.jpg', 'backdrop_path': '/sfT3NqSnjEDY1449qBgQRWOIcaq.jpg'}]",
#  "[{'id': 135179, 'name': 'Sin City Collection', 'poster_path': '/aGgHxGVmjssn7lw1ZucY5U2gI8K.jpg', 'backdrop_path': '/qs200GlvLNIQKUns6AIeLcJWtPT.jpg'}]",
#  "[{'id': 93295, 'name': '48 Hrs. Collection', 'poster_path': '/8Dlcb8aDch6sUcWBc8zSSfNbPgG.jpg', 'backdrop_path': '/hRaxX6WmtukiBvi8ru7RFVQiDYk.jpg'}]",
#  "[{'id': 391739, 'name': 'Cirque du Soleil Collection', 'poster_path': '/nXome5ObjbFONvQkfCu2kgsNcaR.jpg', 'backdrop_path': '/mkMeDXskWSSMGdgAcQQlc6LcjqA.jpg'}]",
#  "[{'id': 416468, 'name': 'World War Z Collection', 'poster_path': '/gDObITaWQUaS9Par6ntLyvq1JrK.jpg', 'backdrop_path': None}]",
#  "[{'id': 264, 'name': 'Back to the Future Collection', 'poster_path': '/UV8VEgAxgKVnCVnZhFACmhxjE4.jpg', 'backdrop_path': '/c9C9Pg2QctyjZHRmS0P8rZg1OTA.jpg'}]",
#  "[{'id': 437451, 'name': 'Cinderella Story Collection', 'poster_path': '/65raP1FRJpPC5GVWVvemQ3kLAKG.jpg', 'backdrop_path': '/iVqkNuy2jpcurdk2ZH2iAexJTo6.jpg'}]",
#  "[{'id': 33085, 'name': 'The Little Mermaid Collection', 'poster_path': '/mwyAzxyGm609qcNJYBRcGNaTblt.jpg', 'backdrop_path': '/eWVVSybV9xkrvGBAx2I721iROPx.jpg'}]",
#  '[{\'id\': 10455, \'name\': "Child\'s Play Collection", \'poster_path\': \'/50aqbDvbOtdlZrje6Qk4ZvKM7dM.jpg\', \'backdrop_path\': \'/AAhYXBVIEl6WgQnzfBsauTIC25.jpg\'}]',
#  "[{'id': 97459, 'name': 'The Jungle Book Collection', 'poster_path': '/uwtMVtIFZy7dfQrR7brKHoDN5H6.jpg', 'backdrop_path': '/b1T7EU7e5XuYHz35iiA0eLg0yKp.jpg'}]",
#  "[{'id': 449462, 'name': 'Super Troopers Collection', 'poster_path': '/lO5B9CinMMFgdkNGTPqPSZN7DWk.jpg', 'backdrop_path': '/v9N8AxyHf9crA9Iza9fF5ntPJFj.jpg'}]",
#  "[{'id': 115776, 'name': 'Robert Langdon Collection', 'poster_path': '/mZDeXsVhBxnWD3tGOQ69vKS3WYL.jpg', 'backdrop_path': '/j1IqpLhCypllamjKe6C2RstjfEQ.jpg'}]",
#  "[{'id': 115838, 'name': 'Escape From ... Collection', 'poster_path': '/8Zih8QGPJNXUuws0fIZmjxjs2Su.jpg', 'backdrop_path': '/c9mWaF2oeodriDLqYQr425sasxo.jpg'}]",
#  "[{'id': 167613, 'name': 'Alvin and the Chipmunks Collection', 'poster_path': '/fLvRQcuk5ZFKnDvUC553XK3OnPC.jpg', 'backdrop_path': '/qI483yHct3PBtIiOH3K3SVNUDq5.jpg'}]",
#  "[{'id': 263, 'name': 'The Dark Knight Collection', 'poster_path': '/bqS2lMgGkuodIXtDILFWTSWDDpa.jpg', 'backdrop_path': '/xfKot7lqaiW4XpL5TtDlVBA9ei9.jpg'}]",
#  "[{'id': 211721, 'name': 'Taxi Collection', 'poster_path': '/nCzy28TbMJDJLxuaPgQZrLgmuT7.jpg', 'backdrop_path': '/74R8bq4RDuxK3F0VPGlse4YH3Ab.jpg'}]",
#  "[{'id': 221539, 'name': 'Dracula (Universal Series)', 'poster_path': '/srgkikGqQD32mhaq8wT6Qz2eLcD.jpg', 'backdrop_path': '/sdbStuQ5qEPZqqWUlNlBd0dPtBT.jpg'}]",
#  "[{'id': 230, 'name': 'The Godfather Collection', 'poster_path': '/7SJVjEDoo7xH62TS8stkqRk4Byo.jpg', 'backdrop_path': '/3WZTxpgscsmoUk81TuECXdFOD0R.jpg'}]",
#  "[{'id': 215456, 'name': 'Keinohrhasen Filmreihe', 'poster_path': '/jRDSPbqRWAHux09eVm1riddAdys.jpg', 'backdrop_path': '/d6huUTFcLRVOHeS70zj8WF4J71U.jpg'}]",
#  "[{'id': 97771, 'name': 'Major League Collection', 'poster_path': '/u4XZNh1jdUsetzQ9XjUQGMgIsdM.jpg', 'backdrop_path': '/vNqeD5ECuhb7FdQiOPCjeI23YK2.jpg'}]",
#  "[{'id': 261307, 'name': 'Alice in Wonderland Collection', 'poster_path': '/xSDwVJEdtewx9pfD125PCdRgznH.jpg', 'backdrop_path': '/xX2mxqqYnG5nmujfZ422iXgXyOO.jpg'}]",
#  "[{'id': 90306, 'name': 'Ghost Rider Collection', 'poster_path': '/bZBasloaMhjxCwH6tV0eziNMqut.jpg', 'backdrop_path': '/ee8zhn4VIXQh1J5t7efyybcvHLj.jpg'}]",
#  "[{'id': 258372, 'name': 'Ivan Tsarevich & the Grey Wolf Collection', 'poster_path': '/dw60cCxHgxcYwzhhgE0GvJjm8WI.jpg', 'backdrop_path': '/e1kU1iZ5KLGQTCSHOIwiUPBeauL.jpg'}]",
#  "[{'id': 247028, 'name': 'Rurouni Kenshin Live-Action Collection', 'poster_path': '/yBYLuwZ1zbRBEKaZmwiThsEqUbC.jpg', 'backdrop_path': '/jqmQLcdn3aEyc30nesZn7qixfoP.jpg'}]",
#  "[{'id': 123255, 'name': 'Prom Night Collection', 'poster_path': '/tHhPnpJad4RVICIwaeERIq63ARg.jpg', 'backdrop_path': None}]",
#  "[{'id': 91361, 'name': 'Halloween Collection', 'poster_path': '/2uqHV6YcD9jEL2WuJYjXiiuRDqd.jpg', 'backdrop_path': '/mmxf1sOe2T1sma0tH0TgTdcit1p.jpg'}]",
#  "[{'id': 410261, 'name': 'A Goofy Movie Collection', 'poster_path': '/4AkuuP5ljZMsAhzVnpzIXPSmDoy.jpg', 'backdrop_path': '/yiLa63gIb7EGH9BbUWXHwI6PMmx.jpg'}]",
#  "[{'id': 387618, 'name': '8MM Collection', 'poster_path': '/8Scc8lBpS2lQs7KPOuxzlm2Z0iP.jpg', 'backdrop_path': '/jgq6X9da6KnEzKNqqb3dYR8bWKy.jpg'}]",
#  "[{'id': 91427, 'name': 'Agent Cody Banks Collection', 'poster_path': '/nQZ1TuxTEFrZLEU02kTTeKogFbX.jpg', 'backdrop_path': '/gh0OZpG16E5LtTAkCRkr5j0v1Fh.jpg'}]",
#  "[{'id': 404609, 'name': 'John Wick Collection', 'poster_path': '/uGhPxTrmT5yASzZrR1oz1ft9UWr.jpg', 'backdrop_path': '/fSwYa5q2xRkBoOOjueLpkLf3N1m.jpg'}]",
#  "[{'id': 34055, 'name': 'Pokémon Collection', 'poster_path': '/j5te0YNZAMXDBnsqTUDKIBEt8iu.jpg', 'backdrop_path': '/iGoYKA0TFfgSoZpG2u5viTJMGfK.jpg'}]",
#  "[{'id': 344555, 'name': 'F*ck You, Goethe Collection', 'poster_path': '/3jH6BgPTXxkBx7N35aTaATzlaG.jpg', 'backdrop_path': '/AtoH8LJQ2sFXfV4gSxxe39XSdzZ.jpg'}]",
#  "[{'id': 1241, 'name': 'Harry Potter Collection', 'poster_path': '/8Xmkc1HvCOpMlbFvVabrtr6HAsp.jpg', 'backdrop_path': '/wfnMt6LGqYHcNyOfsuusw5lX3bL.jpg'}]",
#  "[{'id': 14890, 'name': 'Bad Boys Collection', 'poster_path': '/tSVbihfvVTCbcm0zXKA7L8R6Y9v.jpg', 'backdrop_path': '/yUvBiiC77UY6SyKhfFyLj7DNbfh.jpg'}]",
#  '[{\'id\': 108693, \'name\': "National Lampoon\'s Vacation Collection", \'poster_path\': \'/zvEUkLpDO7xlgabBEA9CCc0cvAt.jpg\', \'backdrop_path\': \'/pBmhj6KkEjlzc3e7jAPkIHgGIrE.jpg\'}]',
#  "[{'id': 313086, 'name': 'The Conjuring Collection', 'poster_path': '/z5VKhNSQKQyxm0co68HAkCqHnmX.jpg', 'backdrop_path': '/opwZzjx69QvbSX1zbC0sc4J4KBX.jpg'}]",
#  "[{'id': 63043, 'name': 'TRON Collection', 'poster_path': '/cvFlDIfOwhYe4ouAAfdyq9E5zlZ.jpg', 'backdrop_path': '/o8NBfffQPE9tHTR9l7FuWbdVPHu.jpg'}]",
#  "[{'id': 241729, 'name': 'Alpha and Omega Collection', 'poster_path': '/mAY1IkH0IoaETKlPu7t7Qj0agbp.jpg', 'backdrop_path': '/234TMV6vkkQZgYMJ2fOc1Gx1QeK.jpg'}]",
#  "[{'id': 656, 'name': 'Saw Collection', 'poster_path': '/xmC2A7qPEfiOkQC58fZh8srWQ5v.jpg', 'backdrop_path': '/oLfS1lOmN2KIU2IQ200SDEPVEZe.jpg'}]",
#  "[{'id': 306031, 'name': 'Pitch Perfect Collection', 'poster_path': '/n1bCFVJeVxX1yCTnXy4OCRwynF1.jpg', 'backdrop_path': '/jolu4gMP6g2VmUZt099U6X6jNNJ.jpg'}]",
#  "[{'id': 123724, 'name': 'Dracula (Hammer Series)', 'poster_path': '/n5SozLvdQZ7cYJb22ZIwNw1DzSg.jpg', 'backdrop_path': '/hybYYwBqaomfePU3uaiJfpg7ykC.jpg'}]",
#  "[{'id': 401562, 'name': 'Teenage Mutant Ninja Turtles (Remake) Collection', 'poster_path': '/i3DywIl37k83YXWreQGIcWNF7kL.jpg', 'backdrop_path': '/tfpOdV9gvqbGJEeLGSu5X1vOLKV.jpg'}]",
#  "[{'id': 52984, 'name': 'National Treasure Collection', 'poster_path': '/z5EIRaI8XS0brelYwDFEVlxcpzM.jpg', 'backdrop_path': '/a0GLVfaDSf5GNZKK5H4FgGCD2VW.jpg'}]",
#  "[{'id': 138706, 'name': 'The Stepfather Collection', 'poster_path': '/6eDLlwDzze6pZVF3lnpLGvKgblX.jpg', 'backdrop_path': None}]",
#  "[{'id': 403374, 'name': 'Jack Reacher Collection', 'poster_path': '/7baSUtFKi8PQ9SLo6ECYBfAW2K8.jpg', 'backdrop_path': '/3FHrAeYMogXd6K1e5tUzQAiS7GE.jpg'}]",
#  "[{'id': 420, 'name': 'The Chronicles of Narnia Collection', 'poster_path': '/sh6Kn8VBfXotJ6qsvJkdfscxXKR.jpg', 'backdrop_path': '/ojjzZUQlqKTsN1T7s5OAVZSjYMH.jpg'}]",
#  '[{\'id\': 304, \'name\': "Ocean\'s Collection", \'poster_path\': \'/rMWeMGBftk6IxNW5mJVH8ZXAvuq.jpg\', \'backdrop_path\': \'/vxmFb03PyjycekffLqXqFibbCzx.jpg\'}]',
#  "[{'id': 85946, 'name': 'District 13 Collection', 'poster_path': '/vNDuGLyr1yT2mY2y41SSWDKiLgu.jpg', 'backdrop_path': '/6d8jbKsWVUKrKBHMcf9mvBkFCgv.jpg'}]",
#  "[{'id': 476065, 'name': 'What the Bleep! Collection', 'poster_path': '/ngXUKFlQ66UqORHoUlLJEmGRCma.jpg', 'backdrop_path': '/gxO7v1S7hInpRI24fH8yhu0DBXd.jpg'}]",
#  "[{'id': 286038, 'name': 'Dead Snow Collection', 'poster_path': '/qhvXYMyPWcFeOsoO4EqOS8T9lwI.jpg', 'backdrop_path': '/nV090IHp1kG5oMgDCmGSYAwkN8D.jpg'}]",
#  "[{'id': 945, 'name': 'Lethal Weapon Collection', 'poster_path': '/5zg6QLY0tdDLVHLwn28oowG3m8H.jpg', 'backdrop_path': '/bSLbqUqs5FzBOb1aO9v7qz71R0U.jpg'}]",
#  "[{'id': 446782, 'name': 'The Disappearance Of Eleanor Rigby', 'poster_path': '/xg3F3P9becOjNqYHlMuBcWPXU5G.jpg', 'backdrop_path': '/3eyH0cwrBdrSCwKF24oOwy8fO7O.jpg'}]",
#  "[{'id': 17178, 'name': 'Jackass Collection', 'poster_path': '/olpnvtLgoScLiCg3YHJ3f27F98f.jpg', 'backdrop_path': '/lidPLbyE1JCUacEDOzkTCncCPBL.jpg'}]",
#  "[{'id': 471435, 'name': 'Wolf Warriors Collection', 'poster_path': '/aDDToktQQPl0TehvHftj8aQo5G7.jpg', 'backdrop_path': '/5OnkBYm7VTFt4jTFB0tMFCQ3zxk.jpg'}]",
#  "[{'id': 109076, 'name': 'Lost Boys Collection', 'poster_path': '/rpuL8zSLmVt34gwk03gSGReSjog.jpg', 'backdrop_path': '/qXpWa7kDopkOyEhuZtOLgIh4SW9.jpg'}]",
#  "[{'id': 104833, 'name': 'Fletch Collection', 'poster_path': '/kf8dk2ASMf0DEi5TZRXK47MDeHU.jpg', 'backdrop_path': '/1mfDXSIPdbpBfTtdjmKnfSuAYUx.jpg'}]",
#  "[{'id': 86311, 'name': 'The Avengers Collection', 'poster_path': '/qJawKUQcIBha507UahUlX0keOT7.jpg', 'backdrop_path': '/zuW6fOiusv4X9nnW3paHGfXcSll.jpg'}]",
#  "[{'id': 1960, 'name': 'Evil Dead Collection', 'poster_path': '/eWFADubShlTEUiNsPcN6BMOKakr.jpg', 'backdrop_path': '/jrLLRe7pctP1aFDRuD9mt59YGHX.jpg'}]",
#  "[{'id': 87220, 'name': 'Smokey and the Bandit Collection', 'poster_path': '/XYTaoh3qo6gYvJ8UAtnY9icY2Z.jpg', 'backdrop_path': '/ldGGb98U7ytidfLHY5wKazeB6MO.jpg'}]",
#  "[{'id': 437628, 'name': 'Constantine Collection', 'poster_path': None, 'backdrop_path': None}]",
#  "[{'id': 8050, 'name': 'Highlander Collection', 'poster_path': '/mNIXoyFicGseg9NoG3NHKZolKze.jpg', 'backdrop_path': '/gY5NPUGGJJdaGPlEM6f2pfHNtit.jpg'}]",
#  "[{'id': 53159, 'name': 'The Santa Clause Collection', 'poster_path': '/1h8iA6i2DpPhsHC65nUB2voVnm5.jpg', 'backdrop_path': '/jQiwVHJN1rsS4DqhF7hlYZTYCH.jpg'}]",
#  "[{'id': 99606, 'name': 'Mean Girls Collection', 'poster_path': '/9XoyvX5uWQRoiz9IodCgUoXLw2V.jpg', 'backdrop_path': None}]",
#  "[{'id': 8650, 'name': 'Transformers Collection', 'poster_path': '/vOUPHWV8aGXq4yYQ2csje5LdT6g.jpg', 'backdrop_path': '/zvZBNNDWd5LcsIBpDhJyCB2MDT7.jpg'}]",
#  "[{'id': 179919, 'name': 'Percy Jackson Collection', 'poster_path': '/fimFFNm5LTSTaYcQEbjrFXT4rgo.jpg', 'backdrop_path': '/a7ptPlBghCbXkLaeSro6bNXFfIe.jpg'}]",
#  "[{'id': 100286, 'name': 'Elizabeth Collection', 'poster_path': '/2XxIeKB6g21GvPmixWyyc9ZlLnR.jpg', 'backdrop_path': '/3YiTOxGX5KZO6P3eg41P50QrRhQ.jpg'}]",
#  "[{'id': 166381, 'name': 'Atlas Shrugged Collection', 'poster_path': '/3xlLe50hlVU1IxEwsFPps08kTzn.jpg', 'backdrop_path': '/bNBqsXH8JSK2zKrYOB217G6IhgE.jpg'}]",
#  "[{'id': 168182, 'name': 'Philo & Clyde Collection', 'poster_path': '/noLaQo6CZSQ3zoBZcgpzfsLMkVk.jpg', 'backdrop_path': '/fAJgSlQ6SENfdjYiengTnoiXgK7.jpg'}]",
#  "[{'id': 222639, 'name': 'Detective Dee Collection', 'poster_path': '/rHTCiaqHZbN6TJjYeq1s42LERCj.jpg', 'backdrop_path': '/7J5E7u3ucpNklNKPIGHTAvgzNWI.jpg'}]",
#  "[{'id': 86058, 'name': 'Dirty Dancing Collection', 'poster_path': '/gkrOvdbCFuGlxVwCYmczw7aw6Ku.jpg', 'backdrop_path': '/qR6POAKwCL8VwuK8ZjSAdRRFNj9.jpg'}]",
#  "[{'id': 51509, 'name': 'Meet the Parents Collection', 'poster_path': '/WFkinadVm4NRynRKuUcaLFNIDx.jpg', 'backdrop_path': '/7UWRq79VHc58QXTSn57UsOUKQLZ.jpg'}]",
#  "[{'id': 278920, 'name': 'Vampires Suck Collection', 'poster_path': '/5lFDNBMJd7Yz6nXWETI8PFVqJXe.jpg', 'backdrop_path': '/rlDK7GYKJP9p1TAj7dIBOuJ7ehO.jpg'}]",
#  "[{'id': 41437, 'name': 'Paranormal Activity Collection', 'poster_path': '/lYXAMmm9XlYmj5Dr4O9diLQVCJS.jpg', 'backdrop_path': '/hZMiAPeINRH0M2X1PBEgn6YdULy.jpg'}]",
#  "[{'id': 201576, 'name': 'The Cabin Fever Collection', 'poster_path': '/u4SLX7S1SdBzaUzPpGWfRaEa1E1.jpg', 'backdrop_path': '/j82lEJUxFlXC35Pi75P3sAbkTUq.jpg'}]",
#  "[{'id': 387219, 'name': 'The Hustler Collection', 'poster_path': '/8kBQvshMpK76aET1hLfAxnDle5W.jpg', 'backdrop_path': None}]",
#  "[{'id': 285564, 'name': 'Jarhead Collection', 'poster_path': '/aRFpBjCseFD6UmahAuLdqS7Or5q.jpg', 'backdrop_path': '/ifSnip5tvaHvxLPAyjkiihE6T2I.jpg'}]",
#  '[{\'id\': 9521, \'name\': "Look Who\'s Talking Collection", \'poster_path\': \'/ez7hA34uLtOuGIwZvwhlpr53tXh.jpg\', \'backdrop_path\': \'/2jEwMXBICqARNmhFFFDu1IvmJCK.jpg\'}]',
#  "[{'id': 145784, 'name': 'The Philadelphia Experiment - Collezione', 'poster_path': '/kXOjvdLpQ3H6eICDMCsZ1wRTJfO.jpg', 'backdrop_path': '/9aTfczTrmq0wAEhXng0zxDsWLV4.jpg'}]",
#  "[{'id': 267922, 'name': 'The Hills Have Eyes (Original) Collection', 'poster_path': '/AbGcpZEihHoR0M7Ls2qTPX4HF60.jpg', 'backdrop_path': '/3Tezeh4KTsqPqFKqatjtd3cAjMk.jpg'}]",
#  "[{'id': 89151, 'name': 'The Gremlins Collection', 'poster_path': '/yiZ18XZHFNjFfEDnEkFCrHVHXcn.jpg', 'backdrop_path': '/2Oz7EyiM9nNeP7appRFkMZNeYRo.jpg'}]",
#  "[{'id': 10456, 'name': 'Dirty Harry Collection', 'poster_path': '/bS1ioomHh2emKAZ6vWn17UZnhDx.jpg', 'backdrop_path': '/nlpixhOhb3JmFqVXKjCwpYFpldf.jpg'}]",
#  "[{'id': 1709, 'name': 'Planet of the Apes Original Collection', 'poster_path': '/r7TBDEcpBAuFoqdtUz7z2nSeFej.jpg', 'backdrop_path': '/eYf3GRnuVCgeFQfEo0qK7ua5rCR.jpg'}]",
#  "[{'id': 221537, 'name': 'Creature From The Black Lagoon (Universal Series)', 'poster_path': '/f41TORvnRk8u9nZ834uxAzxIGuH.jpg', 'backdrop_path': '/jPVq82CMKAm6fKVeW2nyRC2X9Yc.jpg'}]",
#  "[{'id': 115822, 'name': 'Dracula 2000 Collection', 'poster_path': '/pUEwGiauaZXUKTocXmzX7GlyYD4.jpg', 'backdrop_path': '/aD4nL9HsMDU8sCEAe7wdeHMiSr2.jpg'}]",
#  "[{'id': 735, 'name': 'Blade Collection', 'poster_path': '/ltjxGZP6aJrwjl7oOZiiZhFgkF1.jpg', 'backdrop_path': '/ev9QybDDzVSahJQdOb71ZuqNVAo.jpg'}]",
#  "[{'id': 124188, 'name': 'Pulse Collection', 'poster_path': '/ttm2U2EUHXO8v0qrlKVw5SW8grN.jpg', 'backdrop_path': '/9An6u5Eu7h1J3IWxlari934faJl.jpg'}]",
#  "[{'id': 166379, 'name': 'Turbulence Collection', 'poster_path': '/zf9uc7kXnVnD75zwVYSzTdJKUUs.jpg', 'backdrop_path': '/7e6gGVQpTDKK54ByvBDjeqrm8au.jpg'}]",
#  "[{'id': 386818, 'name': 'Django - Original films', 'poster_path': '/jvzJLNcftgLV40upfMozhJRKdvl.jpg', 'backdrop_path': '/kzM0t0wok7gMsRPTxS8a0JuTcGW.jpg'}]",
#  "[{'id': 96676, 'name': 'Never Back Down Collection', 'poster_path': '/2srb1k1nAPHk7lzpheLK8e76Clp.jpg', 'backdrop_path': '/f069jw6rYHIWfypDjzQvODuGSz8.jpg'}]",
#  "[{'id': 404825, 'name': 'Wreck-It Ralph Collection', 'poster_path': '/aa0D0ssoQWTrvTYhwDsRNVc4DQk.jpg', 'backdrop_path': '/maHMw00WEuUzi4hoXxXQAGLntfH.jpg'}]",
#  "[{'id': 270252, 'name': 'Planes Collection', 'poster_path': '/tvzKXcXiJuUwOlni9MV00LCtqNm.jpg', 'backdrop_path': '/zGoePWKFLVJlxDWUUJhxSQgmkCa.jpg'}]",
#  '[{\'id\': 436295, \'name\': "Surf\'s Up Collection", \'poster_path\': \'/7h8x4evTAlErpv7OQwCLpS0KLXm.jpg\', \'backdrop_path\': \'/tkoEC5mLB1lyGiIejCRgulYaeLf.jpg\'}]',
#  "[{'id': 93220, 'name': 'Miss Congeniality Collection', 'poster_path': '/wgQWsSsvB1iu1Pwc4nUP9E5bRzs.jpg', 'backdrop_path': '/7TIT28YbhAOeQGD2q2hJ9j83jI1.jpg'}]",
#  "[{'id': 17368, 'name': 'The Sisterhood of the Traveling Pants Collection', 'poster_path': '/kq1Hu7CmNyKJ5XTW5BK9yqOlQfi.jpg', 'backdrop_path': '/u0kYMfyYCEKuWvf3zZLorEhUKzR.jpg'}]",
#  "[{'id': 122776, 'name': 'Kvartet I Collection', 'poster_path': '/rleIVHx2kG8lYfHUsBh3CkD4Jnc.jpg', 'backdrop_path': '/c7SHTYbGPb3DzO484z0aYFx5u0q.jpg'}]",
#  "[{'id': 8537, 'name': 'Superman Collection', 'poster_path': '/fgTdu62v1jjNDPh68V9TJZMgXbo.jpg', 'backdrop_path': '/la0EhOrgVAiY8sf3ILz3wgoaNXH.jpg'}]",
#  "[{'id': 495, 'name': 'Shaft Collection', 'poster_path': '/z6UFfaPSYIEMZGxiNGuy881hcsH.jpg', 'backdrop_path': '/muZrPdBs937VAx03Giw66x1XGus.jpg'}]",
#  "[{'id': 239766, 'name': 'The Klapisch Trilogy', 'poster_path': '/woD0gFHbZgwi9RpLL0uSQ56hnJA.jpg', 'backdrop_path': '/p7g6oUYWhKS1TmLo4xBMnDNcsGh.jpg'}]",
#  "[{'id': 164397, 'name': 'Class of 1999 Collection', 'poster_path': None, 'backdrop_path': None}]",
#  "[{'id': 8864, 'name': 'Final Destination Collection', 'poster_path': '/mZUyhsfIthTl5rfdeSox702Ircr.jpg', 'backdrop_path': '/y3aWOInifbGKXM34KjtcMITrZRZ.jpg'}]",
#  "[{'id': 119674, 'name': 'Psycho Collection', 'poster_path': '/29pDqAgmb4idzWzuZncoT7LZplA.jpg', 'backdrop_path': '/bPQZkZjNnsYuPZWzoRRl9k0VSQ8.jpg'}]",
#  "[{'id': 124951, 'name': 'Mannequin Collection', 'poster_path': '/tHUiRPu9PmsgDEa4j22fjWHjFkW.jpg', 'backdrop_path': '/qNRyB22N3Y6aGii099by5I51KDJ.jpg'}]",
#  "[{'id': 107473, 'name': 'Ирония судьбы (Коллекция)', 'poster_path': '/1DzMfdobDqF67PhAtLiECqLbsqV.jpg', 'backdrop_path': None}]",
#  "[{'id': 3106, 'name': 'World of Watches Collection', 'poster_path': '/5k6kkMpPCDqelJ2X1RABHCbstE6.jpg', 'backdrop_path': '/nYLhKt0AdNr9IYT2K7p0U3HDY8k.jpg'}]",
#  "[{'id': 9328, 'name': 'Free Willy Collection', 'poster_path': '/3M2Q9ZDTyFBfi3ohz2gizFmnoL0.jpg', 'backdrop_path': '/aef15QAJ8Kxbh8W5zXqJb1f9Vhw.jpg'}]",
#  "[{'id': 402074, 'name': 'Annabelle Collection', 'poster_path': '/zJfExJWUgugWziREAikeAW69poY.jpg', 'backdrop_path': '/AbTHMNaeUO8rUcRZf5J6MRfZE6v.jpg'}]",
#  "[{'id': 30663, 'name': 'Harold & Kumar Collection', 'poster_path': '/9OBP4MQBAXnBZ1uXLZykIWRGnBb.jpg', 'backdrop_path': '/b70mFgsSn2hl3CvC0nRx0SHUEX0.jpg'}]",
#  "[{'id': 106784, 'name': 'Love in the City Collection', 'poster_path': '/xhRO4HSdJv2i5MQIW8nt6PC3JWK.jpg', 'backdrop_path': '/6ZPtYW6h1M4K3URZMr7ZBgmTv8N.jpg'}]",
#  "[{'id': 117927, 'name': 'House of the Dead Collection', 'poster_path': '/jZiLJV1yUez60J361t8fN2zDMEu.jpg', 'backdrop_path': None}]",
#  "[{'id': 1974, 'name': 'The Grudge Collection', 'poster_path': '/dohOSIYDEK42stdfKo0pQfrve0h.jpg', 'backdrop_path': '/nRfDTqIuaVLu2aB0qFuSmw8btp0.jpg'}]",
#  "[{'id': 473843, 'name': 'Stake Land Collection', 'poster_path': '/xAwBPbxAlDnSqhHoDNGNXcsTpIO.jpg', 'backdrop_path': '/ejgCF5HlsM3FwxdgzdoEJ7tFN3C.jpg'}]",
#  "[{'id': 86224, 'name': 'The Saint Collection', 'poster_path': '/3dliYexStkZy6NOAH533Y8oduOj.jpg', 'backdrop_path': None}]",
#  "[{'id': 10194, 'name': 'Toy Story Collection', 'poster_path': '/7G9915LfUQ2lVfwMEEhDsn3kT4B.jpg', 'backdrop_path': '/9FBwqcd9IRruEDUrTdcaafOMKUq.jpg'}]",
#  "[{'id': 357173, 'name': 'Sinister Collection', 'poster_path': '/uun1SgzxdQx9YIPyepoLE3ePxQh.jpg', 'backdrop_path': '/4JASyGk5suaz4xwMp6irzg334k6.jpg'}]",
#  "[{'id': 115225, 'name': 'Children of the Corn Collection', 'poster_path': '/v6auJblMcNxUmZx23mQXMHmzyY3.jpg', 'backdrop_path': '/g4aK8Up5zSegesJdMYbxDcndn20.jpg'}]",
#  "[{'id': 33071, 'name': 'Cheech & Chong Collection', 'poster_path': '/mI9ggvzjaDIGN1qcrM9fvATHVmZ.jpg', 'backdrop_path': '/tJqD18aCja9kNpZ1W2r5gZK2qdq.jpg'}]",
#  "[{'id': 19285, 'name': 'Leprechaun Collection (Original Series)', 'poster_path': '/kdnaM7K8T8oXwWk2QdiWEs8Zg2w.jpg', 'backdrop_path': '/pRjYboGyfjO5PkY7Rdg21s4FhoI.jpg'}]",
#  "[{'id': 89137, 'name': 'How to Train Your Dragon Collection', 'poster_path': '/nJ7ud7XWnNCnGfRQUkUp2t17Sq3.jpg', 'backdrop_path': '/mvcfPkOvgDJG2lEAxTz0NKqoQLo.jpg'}]",
#  "[{'id': 314023, 'name': 'Hercules (Lou Ferrigno) Collection', 'poster_path': '/8u0CHePdPsVPFzDYhZLXtacKl51.jpg', 'backdrop_path': None}]",
#  "[{'id': 1657, 'name': 'Zorro Collection', 'poster_path': '/ziQDmVR3VE0hC0GDWgaQwz0H3Ff.jpg', 'backdrop_path': '/wZCWCe4jPJz04dvVGLQ8TtOq9Js.jpg'}]",
#  "[{'id': 87186, 'name': 'The Boondock Saints Collection', 'poster_path': '/u4hp2I1DgWw2ZnkX2VTZDixGP87.jpg', 'backdrop_path': '/kdxXEiS3sDB7pvQapiqiTRbwkKr.jpg'}]",
#  "[{'id': 9332, 'name': 'Crocodile Dundee Collection', 'poster_path': '/uFYcjCVfr5lsDnWliBWuHgWXgw.jpg', 'backdrop_path': '/pI2EqYQCzCRnrpiFHl8rrGp1qW9.jpg'}]",
#  "[{'id': 97460, 'name': 'Lady and the Tramp Collection', 'poster_path': '/fvk72hTShONXVDDSdoTEVm7DJh0.jpg', 'backdrop_path': '/8YIec6FKfOHn9uw7MMH1200wbyK.jpg'}]",
#  "[{'id': 96677, 'name': 'Red Cliff Collection', 'poster_path': '/3KFgWRuNk3d9QGCnQUXKJSsfrLC.jpg', 'backdrop_path': '/46G7BAqK6LDAxIFVLq926rzN65o.jpg'}]",
#  "[{'id': 3292, 'name': 'Tulse Luper', 'poster_path': None, 'backdrop_path': None}]",
#  "[{'id': 123932, 'name': 'Quarantine Collection', 'poster_path': '/Aa0hh5DGedQPdFs2e43uRzqXw50.jpg', 'backdrop_path': '/7tMlGUiAGrryUimeKDnECC9mWEZ.jpg'}]",
#  "[{'id': 453993, 'name': 'The Wolverine Collection', 'poster_path': '/8Ht4a5A5Ypxh0PjbVoRTzm1kAu3.jpg', 'backdrop_path': '/QtSxEuCwcZSfCTMZfER3nHDVsG.jpg'}]",
#  "[{'id': 221622, 'name': '12 Rounds Collection', 'poster_path': '/l1TBw4KOSWAxYM3RwRFFGq8VG69.jpg', 'backdrop_path': '/cPNJRFgk1EtdqUAOSZ5gPigj741.jpg'}]",
#  "[{'id': 248339, 'name': 'House on Haunted Hill Collection', 'poster_path': '/caGBw1s6C1Fxl8We4fDTmhBnJNk.jpg', 'backdrop_path': '/zDPoIqkC0SGWCQrcKyJpZJZEF1E.jpg'}]",
#  "[{'id': 86116, 'name': 'Death Race Collection', 'poster_path': '/uffHLg0ekFlErCp7OkpecXkWPng.jpg', 'backdrop_path': '/cGaVuq8ZjX1UPD9wPRlzx6lP9kK.jpg'}]",
#  "[{'id': 155474, 'name': 'French Connection Collection', 'poster_path': '/zheN2WhCSS1M8rkjObQGr0dZdvZ.jpg', 'backdrop_path': '/islbdTICsxPE1c3YEFzEc9Wb46p.jpg'}]",
#  "[{'id': 88735, 'name': 'K-9 Collection', 'poster_path': '/moEkdT6SE1HxR9QHwor6DJX8NYe.jpg', 'backdrop_path': '/mdG3H2w9Ktc2Ua6tJie3eUE8Zte.jpg'}]",
#  "[{'id': 295130, 'name': 'The Maze Runner Collection', 'poster_path': '/beR71cbwXH0vySlTMPZo0GQ54Q9.jpg', 'backdrop_path': '/eQ8iwAvGfuNnPjBCKTIVp5PsFw.jpg'}]",
#  "[{'id': 269098, 'name': 'Police Story Collection', 'poster_path': '/zF4gP4w1xxM7jDKLjTDK3ixkkms.jpg', 'backdrop_path': '/5qbfJzkMAUkFxcVo0dqnTRmpUoh.jpg'}]",
#  "[{'id': 240690, 'name': 'Billy Jack Collection', 'poster_path': None, 'backdrop_path': None}]",
#  "[{'id': 64750, 'name': 'Blair Witch Collection', 'poster_path': '/qDQuKJZYLHrs1Ej64tYYFooFxc1.jpg', 'backdrop_path': '/e5GwLq0zBer3SuSJZodcNROnT6Z.jpg'}]",
#  "[{'id': 159616, 'name': 'East is East Collection', 'poster_path': '/aCRRl0LNpFgkwyW66OlcdfwVUs3.jpg', 'backdrop_path': '/tx3cY0yY2xWIT1shMOTOLJH8Nx4.jpg'}]",
#  "[{'id': 173710, 'name': 'Planet of the Apes (Reboot) Collection', 'poster_path': '/qQrEMycfVN2gRlKTLWGn0QdOnSk.jpg', 'backdrop_path': '/mepJpyqVtD6P65vgCU1ngGFEjs5.jpg'}]",
#  "[{'id': 5547, 'name': 'RoboCop Collection', 'poster_path': '/foJBQb9oEOH0mGh77tXyoxXCfzU.jpg', 'backdrop_path': '/azQScQWHpz5puIV4YeCcqgiT9Tn.jpg'}]",
#  "[{'id': 86307, 'name': 'Cocoon Collection', 'poster_path': '/qKtNXCcY3DMJ8T7cs47yDwpU5fT.jpg', 'backdrop_path': '/o32F4wuQJPBnP5FVkOGP9DxGYJI.jpg'}]",
#  "[{'id': 280504, 'name': 'Mechanic Collection', 'poster_path': '/rYW2tVlAwa53xR57ipFytzYhrxq.jpg', 'backdrop_path': '/i36Ufc9CmjwpcfUaQv1YgifPyhF.jpg'}]",
#  "[{'id': 86024, 'name': 'Legally Blonde Collection', 'poster_path': '/kupFjC97HLSqG5CX47NsTJNEyAs.jpg', 'backdrop_path': '/aabPyPAA6E8hJ7tUipwunr3Itzb.jpg'}]",
#  "[{'id': 419784, 'name': 'Masti Collection', 'poster_path': None, 'backdrop_path': None}]",
#  "[{'id': 328, 'name': 'Jurassic Park Collection', 'poster_path': '/qIm2nHXLpBBdMxi8dvfrnDkBUDh.jpg', 'backdrop_path': '/pJjIH9QN0OkHFV9eue6XfRVnPkr.jpg'}]",
#  '[{\'id\': 409343, \'name\': "God\'s Not Dead Collection", \'poster_path\': \'/Pe7qLt83hZbjWGOBJukmDn8Kve.jpg\', \'backdrop_path\': \'/ykT8iDLI2kID4zD0KLWzZjBFQVt.jpg\'}]',
#  "[{'id': 10721, 'name': 'Mimic Collection', 'poster_path': '/oKG4cGU0hw6ONVyjrS2qECQinrg.jpg', 'backdrop_path': '/AmlJVxC6M1BfZgpgtuBoTg1Jwqq.jpg'}]",
#  "[{'id': 528, 'name': 'The Terminator Collection', 'poster_path': '/vxiKtcxAJxHhlg2H1X8y7zcM3k6.jpg', 'backdrop_path': '/cpmbkwSxZnKO69V82A9a34tvk2E.jpg'}]",
#  "[{'id': 31562, 'name': 'The Bourne Collection', 'poster_path': '/lTfOZ25PhQkmGb5NHmaFnwB7b13.jpg', 'backdrop_path': '/vA5xMglyZv7yzDTj1qUTU4OvelV.jpg'}]",
#  "[{'id': 286904, 'name': 'Ultimate Avengers Collection', 'poster_path': '/kUCn2BUhItvzyirayEiv83XNHW8.jpg', 'backdrop_path': '/9DA9dxRE0fRlpl4amBmLCjQdZay.jpg'}]",
#  "[{'id': 439053, 'name': 'Brooklyn Cigar Store Collection', 'poster_path': '/bgiPsYjbjbRFmEeUfYlp8ZDBVJJ.jpg', 'backdrop_path': '/r4Ov7P8OADcOxfpuDujoJl2Cqry.jpg'}]",
#  "[{'id': 24761, 'name': 'The Millennium Collection', 'poster_path': '/sLeE5pwX9cle1v1TpBylT9MeYJ2.jpg', 'backdrop_path': '/9wLsZPhI7ZafO4fh1MhwCjvkclN.jpg'}]",
#  "[{'id': 111751, 'name': 'Texas Chainsaw Massacre Collection', 'poster_path': '/lxYgt4gS4CEvfC2ZCa83IiOsOiu.jpg', 'backdrop_path': '/1zIwt7gUyxKhOKYXN5XNGdGxwHg.jpg'}]",
#  "[{'id': 463394, 'name': 'Always: Sunset on Third Street Collection', 'poster_path': None, 'backdrop_path': None}]",
#  "[{'id': 138908, 'name': '2 Days In... Collection', 'poster_path': '/ffwnytEmZsWSZmb8BH7BblRVBfR.jpg', 'backdrop_path': '/gzj0bdcB3zZ6u5JSfFBd2TRCcAz.jpg'}]",
#  "[{'id': 107467, 'name': 'Самый лучший фильм - Коллекция', 'poster_path': None, 'backdrop_path': None}]",
#  "[{'id': 47770, 'name': 'Phantasm Collection', 'poster_path': '/xqgAkKmQRrk0UaIbWMak4RRSQm7.jpg', 'backdrop_path': '/bu33EKctcBJvN5KHR780lWQkyJd.jpg'}]",
#  "[{'id': 105322, 'name': 'Kickboxer Collection', 'poster_path': '/frOnbHEHWISXBC43wjsrBGOhqGJ.jpg', 'backdrop_path': None}]",
#  "[{'id': 52760, 'name': 'Urban Legend', 'poster_path': '/xhxs9fukHkkFgVcdoWKViiqduLo.jpg', 'backdrop_path': '/hSMhHSKOXLe0VGiDSbTwBbX55xv.jpg'}]",
#  "[{'id': 131295, 'name': 'Captain America Collection', 'poster_path': '/2tOgiY533JSFp7OrVlkeRJvsZpI.jpg', 'backdrop_path': '/nZSYqitBkAvmoq5IrsGsSWuhSC8.jpg'}]",
#  "[{'id': 12087, 'name': 'Herbie Collection', 'poster_path': '/uFvt8t7HlB6BzjiJDU6ea1eI28L.jpg', 'backdrop_path': '/hgi9EeU50KFhv9pCDmJyx4VLp5G.jpg'}]",
#  "[{'id': 86860, 'name': 'Scooby-Doo Collection', 'poster_path': '/YAuhbJKSG1R42QHJmbGsNQ80Fd.jpg', 'backdrop_path': '/aj598PG0VipBkiQXtikXdX5jRR4.jpg'}]",
#  "[{'id': 33938, 'name': 'Airport Collection', 'poster_path': '/yDnEIOmCgPZJ55d8WeRjlgqgi78.jpg', 'backdrop_path': '/aahejNK1UOMWT2FNGOjgQDvczE.jpg'}]",
#  "[{'id': 2980, 'name': 'Ghostbusters Collection', 'poster_path': '/zsSnQq4lGocDkqsrdVUTNNjZz7R.jpg', 'backdrop_path': '/g54JU2Bn4EFezsawnI7ccpAzPC7.jpg'}]",
#  "[{'id': 454520, 'name': 'Captain Harlock Collection', 'poster_path': '/z0NsZNauyNM1ZKj3FCfJvZoSwSA.jpg', 'backdrop_path': '/kpY6iMfKkssuD1WObzoGSIeMguY.jpg'}]",
#  "[{'id': 123213, 'name': 'The Fly (1958 series)', 'poster_path': '/if9PkF46yCeMp9WTYhUOjxnytAt.jpg', 'backdrop_path': '/1MMTGpmm0E9yXRTNyW0YebAs66S.jpg'}]",
#  "[{'id': 222634, 'name': 'Tooth Fairy Collection', 'poster_path': '/2P7Ua3qTgM5COjBfdBV0614wXaw.jpg', 'backdrop_path': '/kyIUMRJHxH2Al3nFNxN63Hnin2p.jpg'}]",
#  "[{'id': 50457, 'name': 'Sex and the City Collection', 'poster_path': '/o3e5Im6iL5tksRBsIS8TnxQK0uv.jpg', 'backdrop_path': '/uM6lHfySQ5sQEuUyMxKdtxsp3CQ.jpg'}]",
#  "[{'id': 124949, 'name': 'Almighty Collection', 'poster_path': '/Abh0z1zf7yYoH8sGLvMIvdNG6gA.jpg', 'backdrop_path': '/qKuR7BpBLTcISNWgxKQmXnYYJFX.jpg'}]",
#  "[{'id': 351684, 'name': 'The Flintstones (Live-Action) Collection', 'poster_path': '/v70Luw2mGhib4s0Osw7Ux8rQgBt.jpg', 'backdrop_path': '/qD0rip0E8EcRcjCPcdu5wUknLZJ.jpg'}]",
#  "[{'id': 112636, 'name': 'The Blues Brothers Collection', 'poster_path': '/pQf9LzCokihzlLmgQlPG7yBpZ1o.jpg', 'backdrop_path': '/i4Jai1IlkbOWd8eNFM0S1lupyLt.jpg'}]",
# ...
#  "[{'id': 4246, 'name': 'Scary Movie Collection', 'poster_path': '/nsD3xlHagixzVYaE57EESeVYro7.jpg', 'backdrop_path': '/qPRZ1HpvpPM81cBTwNKXlqtH9MT.jpg'}]",
#  "[{'id': 284433, 'name': 'Guardians of the Galaxy Collection', 'poster_path': '/iL8mukexAqEg0xK783rG561tdd8.jpg', 'backdrop_path': '/jdyyjulTBU8YUYAUvQFj6U1g2Pj.jpg'}]",
#  "[{'id': 64751, 'name': 'Crank Collection', 'poster_path': '/wmUzRqcAi0KOW7sqnaAvEQtM8l.jpg', 'backdrop_path': '/cziWkSXQG3Vul0l3Mu2sOXLS1dC.jpg'}]",
#  "[{'id': 91945, 'name': 'American Ninja Collection', 'poster_path': '/5cbm8oJR0QlUOxWnSvt3HkcZhb7.jpg', 'backdrop_path': '/znX4o1qtkut4IeprwfEk8uluc4p.jpg'}]",
#  "[{'id': 281644, 'name': 'Rocky Horror Collection', 'poster_path': '/av74GpX6RjxQxPqWm1Hkcbc7dAE.jpg', 'backdrop_path': None}]",
#  "[{'id': 52783, 'name': 'Wall Street Collection', 'poster_path': '/dmGQDIrfvmr5rahYcVhpS2xx6oy.jpg', 'backdrop_path': '/sEKYBSwZFFppJ5GmEVxsECr7ilR.jpg'}]",
#  "[{'id': 272673, 'name': 'Cat People Collection', 'poster_path': '/boK1NQVpce9PS2K7pK0ARA6MCor.jpg', 'backdrop_path': '/mMN1S9UkPntpgD5NkzUqzPDCyMn.jpg'}]",
#  "[{'id': 134897, 'name': 'The Smurfs (Theatrical) Collection', 'poster_path': '/m5p3J2GVAWkHc5UW7mDGXCt7nO7.jpg', 'backdrop_path': '/wMtKE8b0iBt0fZF28vcUiA7ghVt.jpg'}]",
#  "[{'id': 2602, 'name': 'Scream Collection', 'poster_path': '/3DjOcwfd8cTcKBkWTcNntAZajEg.jpg', 'backdrop_path': '/jPTbJp1601vLu27WhyjhpVk8w0h.jpg'}]",
#  "[{'id': 374511, 'name': 'Godzilla (Heisei) Collection', 'poster_path': '/A25nYpiBlYlGdJSuAfN9oJ9Li39.jpg', 'backdrop_path': '/4Y5IXrcWuK1wA3PbeNU5y6Qd3zF.jpg'}]",
#  "[{'id': 476054, 'name': 'The Hitcher (1986) Collection', 'poster_path': '/9GgPZiVFCdN7CkAbEb9fp950Ka5.jpg', 'backdrop_path': '/lyZWcLYvqRbo4emD8mQpBIirtBr.jpg'}]",
#  "[{'id': 168186, 'name': 'Witchboard Collection', 'poster_path': '/qLSZTs14REiR9ZEfV2IOYS6viIZ.jpg', 'backdrop_path': None}]",
#  "[{'id': 295, 'name': 'Pirates of the Caribbean Collection', 'poster_path': '/zT5UKFhq9nk97VGlBbAxlAK8UFN.jpg', 'backdrop_path': '/cnKAGbX1rDkAquF2V1wVkptHDJO.jpg'}]",
#  "[{'id': 3167, 'name': 'Ace Ventura Collection', 'poster_path': '/qCxH543pScFed1CycwJ1nVgrkOc.jpg', 'backdrop_path': '/bswWgdDsLu0fhWMYUzLF8XgiK4h.jpg'}]",
#  "[{'id': 14563, 'name': 'The Ring Collection', 'poster_path': '/500xj7l72BojMZ3tNBJY46tg5YJ.jpg', 'backdrop_path': '/jXlFymc442CEMB5h3d62GeJefnW.jpg'}]",
#  "[{'id': 386534, 'name': '... Has Fallen Collection', 'poster_path': '/kM0U7nzdSepUkC6sOvVrqZkdFk5.jpg', 'backdrop_path': '/w5GjGycHi5EOfPx2JSMshCN7OJn.jpg'}]",
#  "[{'id': 43064, 'name': 'Speed Collection', 'poster_path': '/9poztwq7SXjEETRdWXcJsl58kxV.jpg', 'backdrop_path': '/75mSNcKIkfZSjXDgytC8UFe6vBl.jpg'}]",
#  "[{'id': 87014, 'name': 'Cats & Dogs Collection', 'poster_path': '/mm56m8wd2BBm94FwlelT2fNl6n1.jpg', 'backdrop_path': '/bYM1XFABSpy0QtAEzr7dks8QRWY.jpg'}]",
#  "[{'id': 390096, 'name': 'Hitman Collection', 'poster_path': '/3wYKmCgRmpHQsJAbfGM0axs3gos.jpg', 'backdrop_path': '/weBIyv0mOydPd0GYJl9iDR3RscM.jpg'}]",
#  "[{'id': 109608, 'name': 'Van Helsing Collection', 'poster_path': '/kuqxOT5Ox7mrHUSvwuDCJG6tuRL.jpg', 'backdrop_path': '/uBNNmICsBnLhB2zhQ8PpwoluoYR.jpg'}]",
#  "[{'id': 110021, 'name': 'The Magnificent Seven Collection', 'poster_path': '/qI64OS0Mqloq3wm1x4TWxXEDnVQ.jpg', 'backdrop_path': '/jwevUd9BsWY9QTJZL5bFjWPoyqZ.jpg'}]",
#  "[{'id': 177675, 'name': 'The Last Exorcism Collection', 'poster_path': '/qHW7u9UxFLbKypwkvkE6rpBftn7.jpg', 'backdrop_path': '/jCXId2VCkC4NMfQwSzzWOS6Uld1.jpg'}]",
#  '[{\'id\': 264338, \'name\': "Rosemary\'s Baby Collection", \'poster_path\': \'/yP9DnKsSGcEuHJktQYotND6dsgJ.jpg\', \'backdrop_path\': \'/36RmiFNEbyfTOF3GG17rOyv4XGD.jpg\'}]',
#  '[{\'id\': 44979, \'name\': "Big Momma\'s House Collection", \'poster_path\': \'/nudrKU6mwJOMtZIIyr2fKO1NcDt.jpg\', \'backdrop_path\': \'/G6JKl9hOeErWUw6fO7PAfBOzAn.jpg\'}]',
#  "[{'id': 264914, 'name': 'Eye of the Dolphin Collection', 'poster_path': '/fHB0jPZCMTdc03vG0sQFpJnDjg9.jpg', 'backdrop_path': None}]",
#  "[{'id': 87800, 'name': 'Appleseed Collection', 'poster_path': '/AoM1NzRnSpo6VtIs3wpzKUSObUX.jpg', 'backdrop_path': '/3uFYlHmUZtEGBiwdxtSlphbmfjK.jpg'}]",
#  "[{'id': 126166, 'name': 'The Delta Force Collection', 'poster_path': '/xt10SGPh35qrXrpWikFlVNRNZ7i.jpg', 'backdrop_path': '/coqZkrXTcqtDBcaQRpCGwcGsh6Y.jpg'}]",
#  "[{'id': 158391, 'name': 'The Apu Collection', 'poster_path': '/kDZJiqL5bCWsbdw2WFqwQoYLUhj.jpg', 'backdrop_path': '/b5zCX85EvJpizJzA2WaQmkd6DN6.jpg'}]",
#  "[{'id': 44976, 'name': 'Dhoom Series', 'poster_path': '/qc1R0oO2tb7TFPiql7Aq6QoDwJp.jpg', 'backdrop_path': None}]",
#  "[{'id': 219691, 'name': 'I Spit on Your Grave Collection', 'poster_path': '/twoKFP4fjfOReWw8U13P39cj8xG.jpg', 'backdrop_path': '/y0UVHxtgIT1TtArCibBtk7wKnfT.jpg'}]",
#  "[{'id': 210006, 'name': 'Machete Collection', 'poster_path': '/7kN9MY7htPG0sI598VJK2pB6zEs.jpg', 'backdrop_path': '/vURYjEnOd8if3juhZh6HRcTJs7T.jpg'}]",
#  "[{'id': 397842, 'name': 'The Amityville Horror Collection', 'poster_path': '/8uCu7d43IHPwFfNS2qCyVuRP1cP.jpg', 'backdrop_path': '/kPfuozrsE7pmFFolkR0xFicZDJT.jpg'}]",
#  '[{\'id\': 179244, \'name\': "Pee-wee\'s Collection", \'poster_path\': \'/m806SvjQ9b6FPFEzS2ODG6lbXqk.jpg\', \'backdrop_path\': \'/36PCFtfaB4SNHVaeGZbMiMkchaT.jpg\'}]',
#  "[{'id': 376863, 'name': 'This is England Collection', 'poster_path': None, 'backdrop_path': None}]",
#  "[{'id': 210303, 'name': 'Rebuild of Evangelion', 'poster_path': '/9PYc1kLfWTjIWNgFcEpqSOn8MU3.jpg', 'backdrop_path': '/7XNGejHMPhWpniAmXmDUslXXcwC.jpg'}]",
#  "[{'id': 448150, 'name': 'Deadpool Collection', 'poster_path': '/30c5jO7YEXuF8KiWXLg9m28GWDA.jpg', 'backdrop_path': '/hBQOWY8qWXJVFAc8yLTh1teIu43.jpg'}]",
#  "[{'id': 12263, 'name': 'The Exorcist Collection', 'poster_path': '/wjMqwHkOuDBSOY5MujL5GSdlBTk.jpg', 'backdrop_path': '/gZnEheMdhKxSZQUEzphCHXldud1.jpg'}]",
#  "[{'id': 209131, 'name': 'Man of Steel Collection', 'poster_path': '/rNnIW6xSPeTiIUtsfEhFeIRiJVv.jpg', 'backdrop_path': '/csERw2A3XIsGegkzil6UGpyhqfw.jpg'}]",
#  "[{'id': 86780, 'name': 'Clash of the Titans Collection', 'poster_path': '/3TXIuCHr2m9oZcLJOc5qo9o5WsT.jpg', 'backdrop_path': '/vmE52XvE2yWWQFt4g1x17K070gY.jpg'}]",
#  "[{'id': 124901, 'name': 'Hatchet Collection', 'poster_path': '/5bfVy15nzU4Q9rX3bekEadpy8CR.jpg', 'backdrop_path': '/f3q5nrEJrhRFr0c2proh8Q9x4xx.jpg'}]",
#  "[{'id': 43220, 'name': 'National Lampoon’s Van Wilder Collection', 'poster_path': '/9O9Dtdetrc7shP2CUr5jQqbIexC.jpg', 'backdrop_path': '/afX0zjd1fFYNXrndzD9jd7gHvi3.jpg'}]",
#  "[{'id': 369004, 'name': 'Borsalino Collection', 'poster_path': None, 'backdrop_path': None}]",
#  "[{'id': 96850, 'name': 'Evangelion Collection', 'poster_path': '/abTBQSq28KU5JhLN6iygcrOx03I.jpg', 'backdrop_path': '/zguc4BSy4cbviHd7di67kifnmzD.jpg'}]",
#  "[{'id': 377545, 'name': 'Samurai Trilogy', 'poster_path': '/qt2ZGJezaW4PNR2lzCDbD9q7dIL.jpg', 'backdrop_path': None}]",
#  "[{'id': 86486, 'name': 'Spy Kids Collection', 'poster_path': '/yqpS8N5w7VYo3gmFtHsGwHTV4Td.jpg', 'backdrop_path': '/oxjNAfQJ1OrySttZSeLayky6T9k.jpg'}]",
#  "[{'id': 217704, 'name': 'The Vampire Chronicles', 'poster_path': '/1Iop0dywqQeD5Mm7oRVR8vZ8gkj.jpg', 'backdrop_path': '/5margBoJC97ZrciVpAUc0PiY6Rc.jpg'}]",
#  "[{'id': 178106, 'name': 'Darko Collection', 'poster_path': '/4Oj6ctBucsLvkbKsQMDaDXXR5cu.jpg', 'backdrop_path': '/hja7IzXp6how8eD1WHriI386TGY.jpg'}]",
#  "[{'id': 330605, 'name': 'The Sting Collection', 'poster_path': None, 'backdrop_path': None}]",
#  "[{'id': 122945, 'name': 'The Legend Collection', 'poster_path': '/KDZVL3UVBPHpp3STKcZvOhWz25.jpg', 'backdrop_path': '/xF0U7VuuKFG2W301UhtkmaWuRVu.jpg'}]",
#  "[{'id': 174245, 'name': 'Alien Nation Collection', 'poster_path': '/gsP7dt9uUkkdl0bL4kU9o9jeehO.jpg', 'backdrop_path': '/s8TyKSfmSlvaLKTqJLpkCCIiLK8.jpg'}]",
#  "[{'id': 288491, 'name': 'Dolphin Tale Collection', 'poster_path': '/3Xav3CJrYtUBQ7mB2lKTJ7TSn1q.jpg', 'backdrop_path': '/hEji18uGq2IwKWs2IpWFw9EwlJp.jpg'}]",
#  "[{'id': 266672, 'name': 'Ted Collection', 'poster_path': '/uHKT9b6ptLpttGHlUF95sKQbtqF.jpg', 'backdrop_path': '/dGrNuWhapf8T0WH98xTC4LXgk1G.jpg'}]",
#  "[{'id': 116661, 'name': 'The Arrival Collection', 'poster_path': '/oBBLM2XzrBwjmwWRsPmZ4UuBe7g.jpg', 'backdrop_path': '/rEk9ZLfrYXL87CMEddMaYAOwC39.jpg'}]",
#  "[{'id': 124950, 'name': 'American Graffiti Collection', 'poster_path': '/nXbscwjttQTQ5OWskK7TSi5CSpH.jpg', 'backdrop_path': '/fkQH8aHqLpdDYXyCXdqRgYOhsoN.jpg'}]",
#  "[{'id': 212123, 'name': 'Tiny Times Collection', 'poster_path': None, 'backdrop_path': None}]",
#  "[{'id': 14740, 'name': 'Madagascar Collection', 'poster_path': '/kjA2VkYx929rPKMPFQRb0lPqY3w.jpg', 'backdrop_path': '/lzTIAbvMeGWB7PUrmBZXulGA28M.jpg'}]",
#  "[{'id': 10457, 'name': 'Once Upon a Time in China Collection', 'poster_path': '/gAuv7bhSYFVTYAazFkHOhPRyONi.jpg', 'backdrop_path': '/gQNRJ3ChYVkqGtAOgmWJKr3uw1x.jpg'}]",
#  "[{'id': 106790, 'name': 'Hooked Collection', 'poster_path': '/u1V1AIezEiPUvSJNsLieNX2vGMv.jpg', 'backdrop_path': '/jBmf0mzo9XIJnYx4KQAEwlNmFgd.jpg'}]",
#  "[{'id': 43563, 'name': 'Friday Collection', 'poster_path': '/dWh1Fohgx07AEd4vRUwgIj8BYxD.jpg', 'backdrop_path': '/pXszT8ZWGj3fohU9FY0niA0IDEw.jpg'}]",
#  "[{'id': 165778, 'name': 'We Are From The Future Collection', 'poster_path': '/leG3ZDOpJm3iexLQBjf2B8CiLI3.jpg', 'backdrop_path': None}]",
#  "[{'id': 135498, 'name': 'King Kong (1976 series)', 'poster_path': '/qi6lnlTKDk0khlRunDOn0K2aW9b.jpg', 'backdrop_path': None}]",
#  "[{'id': 395591, 'name': 'Sex and Zen Collection', 'poster_path': '/sFrLDqUMDt3QaBhqWe7b98hOfmv.jpg', 'backdrop_path': None}]",
#  "[{'id': 137697, 'name': 'Finding Nemo Collection', 'poster_path': '/xwggrEugjcJDuabIWvK2CpmK91z.jpg', 'backdrop_path': '/2hC8HHRUvwRljYKIcQDMyMbLlxz.jpg'}]",
#  "[{'id': 106000, 'name': 'Beastmaster Collection', 'poster_path': '/h2WbsEqvWpe3KvT2ArxS1ARSRDl.jpg', 'backdrop_path': '/AeXUmULuf1GFw2YyVbwpxTsTXH.jpg'}]",
#  "[{'id': 93369, 'name': 'Ringu Collection', 'poster_path': '/eQX9SK5WPdsKWRGLfga4w9KuskV.jpg', 'backdrop_path': '/aS42DTtR6UYNLfKdKJBKYL1OS1U.jpg'}]",
#  "[{'id': 96937, 'name': 'The Boogeyman Collection', 'poster_path': '/rR4Vga4sQhD4YTF7QtMxkfMvN6F.jpg', 'backdrop_path': '/oVP6PrxHf4D745QJ2Pp8ojSpcqF.jpg'}]",
#  "[{'id': 176097, 'name': 'Barbershop Collection', 'poster_path': '/glSSzT4jwKblxxGXN0lHWxbyhUH.jpg', 'backdrop_path': '/lCvX9g4vvxFUgJGNlFwfkZJWGiB.jpg'}]",
#  "[{'id': 110127, 'name': 'Analyze Collection', 'poster_path': '/cujx4R1DmJdjIdiCWtQULIvCyix.jpg', 'backdrop_path': '/bNcKGfgqck8SQALVlZcMRcjOwBE.jpg'}]",
#  "[{'id': 43058, 'name': 'Homeward Bound Collection', 'poster_path': '/4S9WMNUJFzxKOjcoS1mGrKFfygI.jpg', 'backdrop_path': None}]",
#  "[{'id': 184977, 'name': 'Shaolin Temple Collection', 'poster_path': '/3VCGnNA68EjALSveGv7rVbWKDd5.jpg', 'backdrop_path': '/grC83MtaWyTbUcxndTK3khIWiMT.jpg'}]",
#  "[{'id': 212562, 'name': 'Jump Street Collection', 'poster_path': '/vufY0iuDNXGEdYOgZNcJFAEZeak.jpg', 'backdrop_path': '/iiAbTNYXpMadPDH4MkjUoJzcGn4.jpg'}]",
#  '[{\'id\': 232844, \'name\': "Nim\'s Island Collection", \'poster_path\': \'/rRPq295zZflnjp9Y8uhJppJBayQ.jpg\', \'backdrop_path\': \'/iRh0E4dR2m7ZiJQ9u58r8jPV0WU.jpg\'}]',
#  "[{'id': 10522, 'name': 'Starship Troopers Collection', 'poster_path': '/uumu3Xj1ME1632SCsyVJwITgOKZ.jpg', 'backdrop_path': '/hwZXCuY6GVw50o17nDGbSR8WMFJ.jpg'}]",
#  "[{'id': 87359, 'name': 'Mission: Impossible Collection', 'poster_path': '/gwyJPIhCK4Xz2WogeBnhCSQfUek.jpg', 'backdrop_path': '/49L0c5utmm0A4BkeDafM9BOhyBT.jpg'}]",
#  "[{'id': 44215, 'name': 'Stargate SG-1 Collection', 'poster_path': '/5TTU7voIo3t0IYzZTPQQAbawy6Y.jpg', 'backdrop_path': '/fwVVh9o0WZsZNstpX3O55ff7Hs8.jpg'}]",
#  "[{'id': 141290, 'name': 'The Lord of the Rings Animated Collection', 'poster_path': '/pQuazFOlGRdn2Lb3oWFJYPeASOc.jpg', 'backdrop_path': '/uUG532EWfyhtKDzsA0sLb1PsHhL.jpg'}]",
#  "[{'id': 136214, 'name': 'Pocahontas Collection', 'poster_path': '/s4RkDe4AjwyrlltdF6Ui7INlME6.jpg', 'backdrop_path': '/qqeOxNmtAW7WXdbrmQftgluvve7.jpg'}]",
#  "[{'id': 14377, 'name': 'Death Wish Collection', 'poster_path': '/3mC5lppASzZHx5IlmFSL6cPQpCP.jpg', 'backdrop_path': '/m3K7AXN8Wi6VIRtVlpF1E6nzEn1.jpg'}]",
#  "[{'id': 10789, 'name': 'Pet Sematary Collection', 'poster_path': '/iySOPKFg4DgtjY9ySsJZoccMcIB.jpg', 'backdrop_path': '/vK18Xz065I4BvRB8r9IrH98ebVp.jpg'}]",
#  "[{'id': 257960, 'name': 'The Raid Collection', 'poster_path': '/dXNof3qb8sY9QOmJ7jdU48ILH7e.jpg', 'backdrop_path': '/oRQ7INsPDVon7U2jphXDr7LSP3H.jpg'}]",
#  "[{'id': 87228, 'name': 'Swamp Thing Collection', 'poster_path': '/niEEDNB366pMOI5RRcw36QGaGDm.jpg', 'backdrop_path': '/w0jv6vdKe3TGOLaCgPbZOu85gas.jpg'}]",
#  "[{'id': 116669, 'name': 'The Scorpion King Collection', 'poster_path': '/qFVW76HRCJFRtTha1vZO1tjYVQ1.jpg', 'backdrop_path': None}]",
#  "[{'id': 312735, 'name': 'Annie Collection', 'poster_path': '/gKQghFIfPL7aviK7OonirYgnaMa.jpg', 'backdrop_path': None}]",
#  "[{'id': 100965, 'name': 'Atlantis Collection', 'poster_path': '/l9wffaf3zMw2fOYDnMrU479IeBv.jpg', 'backdrop_path': '/vJOfi2m9yaQGu7LPRcBL44KDU7r.jpg'}]",
#  "[{'id': 468222, 'name': 'The Incredibles Collection', 'poster_path': '/p5E9owiVpQqAoSEl1VpcC4i5z8Q.jpg', 'backdrop_path': '/9eDW2dVhnzPS2HvaRdK2OlAGaLq.jpg'}]",
#  "[{'id': 43055, 'name': 'Conan the Barbarian Collection', 'poster_path': '/vguM8mJmArTn9ePTm8fK0Ryt7EI.jpg', 'backdrop_path': '/lGhx5lQiPJ79piSrXHgN5pSmJjh.jpg'}]",
#  "[{'id': 97445, 'name': 'Air Bud Collection', 'poster_path': '/6uJ2GXA5kBskJx6emTuHyp2S3ww.jpg', 'backdrop_path': '/3iROV2GdrAFz6lbrGneQLt8lc7K.jpg'}]",
#  "[{'id': 315595, 'name': 'Tinker Bell Collection', 'poster_path': '/nTEOjP7JpFa9VZlawzqNBy4g5KY.jpg', 'backdrop_path': '/8wvxr06XNW2zofbOHQqEgokTmLx.jpg'}]",
#  "[{'id': 476961, 'name': 'Goon Collection', 'poster_path': '/uHKl6JXibu1MstyAlT1d3I4YKb6.jpg', 'backdrop_path': None}]",
#  "[{'id': 286951, 'name': 'Singham Collection', 'poster_path': None, 'backdrop_path': None}]",
#  "[{'id': 188197, 'name': 'Cetto La Qualunque - Collezione', 'poster_path': '/kDrDEoSGTDo7tVd4QOOtKxIe9gz.jpg', 'backdrop_path': '/u6PrL2x3dU8cZNgDNl0qzb5hpJA.jpg'}]",
#  "[{'id': 19387, 'name': 'The X-Files Collection', 'poster_path': '/uqvuUgReZ5Y5C7S7axeRxE8zSM1.jpg', 'backdrop_path': '/22p3xTTuXc9FEnzyGlfB9KBtR4Y.jpg'}]",
#  "[{'id': 166378, 'name': 'Joy Ride Collection', 'poster_path': '/ln6CZn4pEBOea3757FaMukhgp25.jpg', 'backdrop_path': '/eDU0xWJge0Sj2A1hyp5NtTcc3OZ.jpg'}]",
#  "[{'id': 479888, 'name': 'The Thing Collection', 'poster_path': '/9O8LH1fyDNIR26UdtQK4NLGbvLI.jpg', 'backdrop_path': '/lUPruOqjDhZrCKz9Ze2tCufPxHR.jpg'}]",
#  "[{'id': 424202, 'name': 'Trainspotting Collection', 'poster_path': '/6W9nyZ3Daq4zHkfTRIzNgWg6ai6.jpg', 'backdrop_path': '/rIrAfUd5wjkGoDkecNx1aXjGJLu.jpg'}]",
#  "[{'id': 23170, 'name': 'Burnt by the Sun Trilogy', 'poster_path': '/prqpHdXvfzz8uYwGPaHj62XfJ1H.jpg', 'backdrop_path': '/h062iMfHieuKdeujaSZBmdYlgRw.jpg'}]",
#  "[{'id': 9743, 'name': 'The Hannibal Lecter Anthology', 'poster_path': '/aRbyr3KsdmIczGh6VrlvlgQdwMQ.jpg', 'backdrop_path': '/npCbvak9UhjPsZB9Oa2k2jsqI7E.jpg'}]",
#  "[{'id': 363966, 'name': 'Care Bears Collection', 'poster_path': None, 'backdrop_path': None}]",
#  "[{'id': 135416, 'name': 'Prometheus Collection', 'poster_path': '/gMjiXB5dhV8nN77xXnhTIhARE7a.jpg', 'backdrop_path': '/cK83Pq8SJoeSTnLJucr8IWn35KF.jpg'}]",
#  '[{\'id\': 109592, \'name\': "Porky\'s Collection", \'poster_path\': \'/fGnfEA244AKrKgcN6uyvEFCgaR6.jpg\', \'backdrop_path\': \'/1Ra6Un73JwIjGHfEU0lM3397Q8z.jpg\'}]',
#  "[{'id': 97307, 'name': 'BloodRayne Collection', 'poster_path': '/yDRE2eRQIGKKpW1AJ9WWolmccOQ.jpg', 'backdrop_path': '/tSiYzuDL8i3yyVyCnxGtwLjA3Tz.jpg'}]",
#  "[{'id': 149704, 'name': 'Alone in the Dark Collection', 'poster_path': '/pCUq2wPTjmpRRTsatXWseAoMzyi.jpg', 'backdrop_path': '/uxhIfa4gqxh9rjGq3vPLoXjQLIY.jpg'}]",
#  "[{'id': 221111, 'name': 'S.W.A.T. Collection', 'poster_path': '/iaBn9GPUik9xwfHIelzTXJi5ClY.jpg', 'backdrop_path': '/75To7hSFaAuciz4EXAFfj4LH6Od.jpg'}]",
#  "[{'id': 107469, 'name': 'Save The Last Dance Collection', 'poster_path': '/jAByXoHn29RlCjIrOa3k1jl60DB.jpg', 'backdrop_path': None}]"]

# %%
df.original_language.nunique()
# Out:
# 36

# %%
df.status.nunique()
# Out:
# 2

# %%
df['original_language'].value_counts()
# Out:
# en    2575
# fr      78
# ru      47
# es      43
# hi      42
# ja      37
# it      24
# cn      20
# ko      20
# zh      19
# de      18
# ta      16
# sv       8
# nl       6
# pt       6
# fa       5
# da       5
# ro       4
# hu       3
# tr       3
# no       2
# ml       2
# pl       2
# te       2
# fi       2
# ur       1
# he       1
# el       1
# ar       1
# nb       1
# vi       1
# mr       1
# cs       1
# sr       1
# bn       1
# id       1
# Name: original_language, dtype: int64

# %%
df['belongs_to_collection'].value_counts()
# Out:
# [{'id': 645, 'name': 'James Bond Collection', 'poster_path': '/HORpg5CSkmeQlAolx3bKMrKgfi.jpg', 'backdrop_path': '/6VcVl48kNKvdXOZfJPdarlUGOsk.jpg'}]                      16
# [{'id': 9735, 'name': 'Friday the 13th Collection', 'poster_path': '/uobgqpLQff9WvxGKE2OSvXv1RHm.jpg', 'backdrop_path': '/c7pMKwv5NzIN6N3KM4L8fYMTtPw.jpg'}]                7
# [{'id': 937, 'name': 'The Pink Panther (Original) Collection', 'poster_path': '/xu6gZ0zGUSR8SC2QLKFaUrX2niM.jpg', 'backdrop_path': '/6KE7AguGR3UqwUn5RkzkoBc3MLy.jpg'}]     6
# [{'id': 9338, 'name': 'Police Academy Collection', 'poster_path': '/1VRdXVy2FYlX4EtllnLKWK6kYDJ.jpg', 'backdrop_path': '/RhpI828r9EKPV4x0pyHiqCDZDQ.jpg'}]                  5
# [{'id': 34055, 'name': 'Pokémon Collection', 'poster_path': '/j5te0YNZAMXDBnsqTUDKIBEt8iu.jpg', 'backdrop_path': '/iGoYKA0TFfgSoZpG2u5viTJMGfK.jpg'}]                       5
#                                                                                                                                                                            ..
# [{'id': 306031, 'name': 'Pitch Perfect Collection', 'poster_path': '/n1bCFVJeVxX1yCTnXy4OCRwynF1.jpg', 'backdrop_path': '/jolu4gMP6g2VmUZt099U6X6jNNJ.jpg'}]                1
# [{'id': 241729, 'name': 'Alpha and Omega Collection', 'poster_path': '/mAY1IkH0IoaETKlPu7t7Qj0agbp.jpg', 'backdrop_path': '/234TMV6vkkQZgYMJ2fOc1Gx1QeK.jpg'}]              1
# [{'id': 14890, 'name': 'Bad Boys Collection', 'poster_path': '/tSVbihfvVTCbcm0zXKA7L8R6Y9v.jpg', 'backdrop_path': '/yUvBiiC77UY6SyKhfFyLj7DNbfh.jpg'}]                      1
# [{'id': 344555, 'name': 'F*ck You, Goethe Collection', 'poster_path': '/3jH6BgPTXxkBx7N35aTaATzlaG.jpg', 'backdrop_path': '/AtoH8LJQ2sFXfV4gSxxe39XSdzZ.jpg'}]              1
# [{'id': 107469, 'name': 'Save The Last Dance Collection', 'poster_path': '/jAByXoHn29RlCjIrOa3k1jl60DB.jpg', 'backdrop_path': None}]                                        1
# Name: belongs_to_collection, Length: 422, dtype: int64

# %%
df['status'].value_counts()
# Out:
# Released    2996
# Rumored        4
# Name: status, dtype: int64

# %%
df['homepage'].isnull()
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4        True
#         ...
# 2995     True
# 2996     True
# 2997     True
# 2998    False
# 2999    False
# Name: homepage, Length: 3000, dtype: bool

# %%
df[~df['homepage'].isnull()]
# Out:
#         id                              belongs_to_collection    budget  \
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 6        7                                                NaN  14000000
# 12      13                                                NaN  15000000
# 15      16                                                NaN    500000
# ...    ...                                                ...       ...
# 2984  2985  [{'id': 221111, 'name': 'S.W.A.T. Collection',...  80000000
# 2985  2986                                                NaN  37665000
# 2993  2994                                                NaN  60000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# 2                         [{'id': 18, 'name': 'Drama'}]
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 6     [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 12                        [{'id': 18, 'name': 'Drama'}]
# 15    [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# ...                                                 ...
# 2984  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 2985  [{'id': 18, 'name': 'Drama'}, {'id': 53, 'name...
# 2993  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                                homepage    imdb_id  \
# 2                     http://sonyclassics.com/whiplash/  tt2582802
# 3                            http://kahaanithefilm.com/  tt1821480
# 6                    http://www.thepossessionmovie.com/  tt0431021
# 12                        http://www.dreamworks.com/ab/  tt0169547
# 15                http://skinningmovie.com/synopsis.htm  tt1129437
# ...                                                 ...        ...
# 2984        http://www.sonypictures.com/homevideo/swat/  tt0257076
# 2985  http://www.sonypictures.com/homevideo/freedoml...  tt0349467
# 2993               http://www.theterminal-themovie.com/  tt0362227
# 2998                     http://www.alongcamepolly.com/  tt0343135
# 2999                   http://www.abductionthefilm.com/  tt1600195
#
#      original_language    original_title  \
# 2                   en          Whiplash
# 3                   hi           Kahaani
# 6                   en    The Possession
# 12                  en   American Beauty
# 15                  sr           Šišanje
# ...                ...               ...
# 2984                en          S.W.A.T.
# 2985                en       Freedomland
# 2993                en      The Terminal
# 2998                en  Along Came Polly
# 2999                en         Abduction
#
#                                                overview  popularity  ...  \
# 2     Under the direction of a ruthless instructor, ...   64.299990  ...
# 3     Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 6     A young girl buys an antique box at a yard sal...    7.286477  ...
# 12    Lester Burnham, a depressed suburban father in...   20.726578  ...
# 15    Novica is a mathematics champion in a Belgrade...    1.018477  ...
# ...                                                 ...         ...  ...
# 2984  Hondo Harrelson recruits Jim Street to join an...   13.334952  ...
# 2985  A black police detective must solve a strange ...    5.388535  ...
# 2993  Viktor Navorski is a man without a country; hi...   14.092373  ...
# 2998  Reuben Feffer is a guy who's spent his entire ...   15.725542  ...
# 2999  A young man sets out to uncover the truth abou...   10.512109  ...
#
#                  title                                           Keywords  \
# 2             Whiplash  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3              Kahaani  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 6       The Possession                                                NaN
# 12     American Beauty  [{'id': 255, 'name': 'male nudity'}, {'id': 29...
# 15            Skinning  [{'id': 379, 'name': 'skinhead'}, {'id': 7492,...
# ...                ...                                                ...
# 2984          S.W.A.T.  [{'id': 2434, 'name': 'liberation'}, {'id': 35...
# 2985       Freedomland  [{'id': 577, 'name': 'black people'}, {'id': 5...
# 2993      The Terminal  [{'id': 242, 'name': 'new york'}, {'id': 822, ...
# 2998  Along Came Polly  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
# 2999         Abduction  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#       cast                                               crew      revenue  \
# 2        3  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...          NaN
# 3        4  [{'credit_id': '52fe48779251416c9108d6eb', 'de...          NaN
# 6        7  [{'credit_id': '52fe4981c3a368484e12ee29', 'de...   85446075.0
# 12      13  [{'credit_id': '52fe420ec3a36847f80007c5', 'de...  356296601.0
# 15      16  [{'credit_id': '52fe4927c3a36847f818bb5f', 'de...        198.0
# ...    ...                                                ...          ...
# 2984  2985  [{'credit_id': '5379d4980e0a261431006f58', 'de...  116643346.0
# 2985  2986  [{'credit_id': '52fe4551c3a36847f80c76e7', 'de...   14655628.0
# 2993  2994  [{'credit_id': '52fe4259c3a36847f8017699', 'de...  219417255.0
# 2998  2999  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386.0
# 2999  3000  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155.0
#
#      half_runtime movie_profit capitalised title   new_profit new_release_date
# 2            52.5      9792000          whiplash          NaN       2014-10-10
# 3            61.0     14800000           kahaani          NaN       2012-03-09
# 6            46.0     71446075    the possession   71446075.0       2012-08-30
# 12           61.0    341296601   american beauty  341296601.0       1999-09-15
# 15           48.5      -499802          skinning    -499802.0       2010-10-06
# ...           ...          ...               ...          ...              ...
# 2984         58.5     36643346          s.w.a.t.   36643346.0       2003-08-08
# 2985         56.5    -23009372       freedomland  -23009372.0       2006-02-17
# 2993         64.0    159417255      the terminal  159417255.0       2004-06-17
# 2998         45.0    129963386  along came polly  129963386.0       2004-01-16
# 2999         53.0     47087155         abduction   47087155.0       2011-09-22
#
# [946 rows x 28 columns]

# %%
df['homepage'].fillna('Not Present',inplace = True)

# %%
df.head(10)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
# 5   6                                                NaN   8000000
# 6   7                                                NaN  14000000
# 7   8                                                NaN         0
# 8   9  [{'id': 256377, 'name': 'The Muppet Collection...         0
# 9  10                                                NaN   6000000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# 5  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...
# 6  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 7                [{'id': 99, 'name': 'Documentary'}]
# 8  [{'id': 28, 'name': 'Action'}, {'id': 35, 'nam...
# 9  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
#
#                              homepage    imdb_id original_language  \
# 0                         Not Present  tt2637294                en
# 1                         Not Present  tt0368933                en
# 2   http://sonyclassics.com/whiplash/  tt2582802                en
# 3          http://kahaanithefilm.com/  tt1821480                hi
# 4                         Not Present  tt1380152                ko
# 5                         Not Present  tt0093743                en
# 6  http://www.thepossessionmovie.com/  tt0431021                en
# 7                         Not Present  tt0391024                en
# 8                         Not Present  tt0117110                en
# 9                         Not Present  tt0310281                en
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
# 5    Pinocchio and the Emperor of the Night
# 6                            The Possession
# 7                              Control Room
# 8                    Muppet Treasure Island
# 9                             A Mighty Wind
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
# 5  Pinocchio and his friends, a glow worm and a m...    0.743274  ...
# 6  A young girl buys an antique box at a yard sal...    7.286477  ...
# 7  A chronicle which provides a rare window into ...    1.949044  ...
# 8  After telling the story of Flint's last journe...    6.902423  ...
# 9  In "A Mighty Wind", director Christopher Guest...    4.672036  ...
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
# 5    Pinocchio and the Emperor of the Night
# 6                            The Possession
# 7                              Control Room
# 8                    Muppet Treasure Island
# 9                             A Mighty Wind
#
#                                             Keywords cast  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...    1
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...    2
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...    3
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...    4
# 4                                                NaN    5
# 5                                                NaN    6
# 6                                                NaN    7
# 7  [{'id': 917, 'name': 'journalism'}, {'id': 163...    8
# 8  [{'id': 2041, 'name': 'island'}, {'id': 4418, ...    9
# 9  [{'id': 11800, 'name': 'mockumentary'}, {'id':...   10
#
#                                                 crew     revenue half_runtime  \
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...         NaN         46.5
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...         NaN         56.5
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...         NaN         52.5
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...         NaN         61.0
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...   3923970.0         59.0
# 5  [{'credit_id': '52fe46f49251416c9106558b', 'de...   3261638.0         41.5
# 6  [{'credit_id': '52fe4981c3a368484e12ee29', 'de...  85446075.0         46.0
# 7  [{'credit_id': '52fe47a69251416c750a0daf', 'de...   2586511.0         42.0
# 8  [{'credit_id': '52fe43c89251416c7501deb3', 'de...  34327391.0         50.0
# 9  [{'credit_id': '52fe45609251416c750545b3', 'de...  18750246.0         45.5
#
#   movie_profit                         capitalised title  new_profit  \
# 0     -1685349                    hot tub time machine 2         NaN
# 1     55149435  the princess diaries 2: royal engagement         NaN
# 2      9792000                                  whiplash         NaN
# 3     14800000                                   kahaani         NaN
# 4      3923970                                marine boy   3923970.0
# 5     -4738362    pinocchio and the emperor of the night  -4738362.0
# 6     71446075                            the possession  71446075.0
# 7      2586511                              control room   2586511.0
# 8     34327391                    muppet treasure island  34327391.0
# 9     12750246                             a mighty wind  12750246.0
#
#   new_release_date
# 0       2015-02-20
# 1       2004-08-06
# 2       2014-10-10
# 3       2012-03-09
# 4       2009-02-05
# 5       1987-08-06
# 6       2012-08-30
# 7       2004-01-15
# 8       1996-02-16
# 9       2003-04-16
#
# [10 rows x 28 columns]

# %%
df['belongs_to_collection'].fillna('Not Present',inplace = True)

# %%
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                        Not Present   3300000
# 3   4                                        Not Present   1200000
# 4   5                                        Not Present         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                        Not Present  tt2637294                en
# 1                        Not Present  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
# 4                        Not Present  tt1380152                ko
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                      마린보이
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4  Marine Boy is the story of a former national s...    1.148070  ...
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
# 4                                Marine Boy
#
#                                             Keywords cast  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...    1
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...    2
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...    3
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...    4
# 4                                                NaN    5
#
#                                                 crew    revenue half_runtime  \
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...        NaN         46.5
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...        NaN         56.5
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...        NaN         52.5
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...        NaN         61.0
# 4  [{'credit_id': '52fe464b9251416c75073b43', 'de...  3923970.0         59.0
#
#   movie_profit                         capitalised title new_profit  \
# 0     -1685349                    hot tub time machine 2        NaN
# 1     55149435  the princess diaries 2: royal engagement        NaN
# 2      9792000                                  whiplash        NaN
# 3     14800000                                   kahaani        NaN
# 4      3923970                                marine boy  3923970.0
#
#   new_release_date
# 0       2015-02-20
# 1       2004-08-06
# 2       2014-10-10
# 3       2012-03-09
# 4       2009-02-05
#
# [5 rows x 28 columns]
